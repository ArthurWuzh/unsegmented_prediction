# %%
import os
import sys
from tqdm import tqdm
from tensorboardX import SummaryWriter
import shutil
import argparse
import logging
import time
import random
import numpy as np

import torch
import torch.optim as optim
from torchvision import transforms
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
from torch.utils.data import DataLoader
from torchvision.utils import make_grid

from networks.vnet import VNet
# from utils.losses import dice_loss
from utils import ramps, losses
from dataloaders.la_heart_sitk import LAHeart, RandomScale, RandomNoise, RandomCrop, CenterCrop, RandomRot, RandomFlip, ToTensor, TwoStreamBatchSampler
# -

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--root_path', type=str, default='../../data/gz_dataset/segmented', help='Name of Experiment')
parser.add_argument('--exp', type=str,  default='vnet_supervisedonly_dp', help='model_name')
parser.add_argument('--max_iterations', type=int,  default=6000, help='maximum epoch number to train')
parser.add_argument('--batch_size', type=int, default=8, help='batch_size per gpu')
parser.add_argument('--base_lr', type=float,  default=0.01, help='maximum epoch number to train')
parser.add_argument('--deterministic', type=int,  default=1, help='whether use deterministic training')
parser.add_argument('--seed', type=int,  default=1337, help='random seed')
parser.add_argument('--gpu', type=str,  default='0', help='GPU to use')
args = parser.parse_args(args=[])

train_data_path = args.root_path
snapshot_path = "../model/" + args.exp + "/"

os.environ['CUDA_VISIBLE_DEVICES'] = args.gpu
batch_size = args.batch_size * len(args.gpu.split(','))
max_iterations = args.max_iterations
base_lr = args.base_lr

# %%
if args.deterministic:
    cudnn.benchmark = False
    cudnn.deterministic = True
    random.seed(args.seed)
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    torch.cuda.manual_seed(args.seed)

num_classes = 4
patch_size = (128, 128, 64)
cls_weights = [1,5,5,15]

# %%
if not os.path.exists(snapshot_path):
    os.makedirs(snapshot_path)
if os.path.exists(snapshot_path + '/code'):
    shutil.rmtree(snapshot_path + '/code')
shutil.copytree('.', snapshot_path + '/code', shutil.ignore_patterns(['.git','__pycache__']))

logging.basicConfig(filename=snapshot_path+"/log.txt", level=logging.INFO,
                    format='[%(asctime)s.%(msecs)03d] %(message)s', datefmt='%H:%M:%S')
logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
logging.info(str(args))

net = VNet(n_channels=1, n_classes=num_classes, normalization='batchnorm', has_dropout=True)
net = net.cuda()

db_train = LAHeart(base_dir=train_data_path,
                    split='train',
                    #num=16,
                    transform = transforms.Compose([
#                       RandomScale(ratio_low=0.6, ratio_high=1.5),
                        RandomNoise(mu=0, sigma=0.05),
                        RandomRot(),
                        RandomFlip(),
                        RandomCrop(patch_size),
                        ToTensor(),
                        ]))
db_test = LAHeart(base_dir=train_data_path,
                    split='test',
                    transform = transforms.Compose([
                        CenterCrop(patch_size),
                        ToTensor()
                    ]))
def worker_init_fn(worker_id):
    random.seed(args.seed+worker_id)
trainloader = DataLoader(
    db_train, 
    batch_size=batch_size, 
    shuffle=True,  
    num_workers=6,#4, 
    pin_memory=True, 
    worker_init_fn=worker_init_fn
)

net.train()
optimizer = optim.SGD(net.parameters(), lr=base_lr, momentum=0.9, weight_decay=0.0001)

writer = SummaryWriter(snapshot_path+'/log')
logging.info("{} itertations per epoch".format(len(trainloader)))

iter_num = 0
max_epoch = max_iterations//len(trainloader)+1
lr_ = base_lr
net.train()
for epoch_num in tqdm(range(max_epoch), ncols=70):
    time1 = time.time()
    for i_batch, sampled_batch in enumerate(trainloader):
#           import pdb
#           pdb.set_trace()
        time2 = time.time()
        # print('fetch data cost {}'.format(time2-time1))
        volume_batch, label_batch = sampled_batch['image'], sampled_batch['label']
        volume_batch, label_batch = volume_batch.cuda(), label_batch.cuda()
        outputs = net(volume_batch)
        
        loss_seg = F.cross_entropy( outputs, label_batch, weight=torch.tensor(cls_weights,dtype=torch.float32).cuda() )
        outputs_soft = F.softmax(outputs, dim=1)
        loss_seg_dice = 0
        print('\n')
        for i in range(num_classes):
            loss_mid = losses.dice_loss(outputs_soft[:, i, :, :, :], label_batch == i )
            loss_seg_dice += loss_mid
            print('dice score (1-dice_loss): {:.3f}'.format(1-loss_mid))
        print('dicetotal:{:.3f}'.format( loss_seg_dice))
        loss = 0.5*(loss_seg+loss_seg_dice)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        iter_num = iter_num + 1
        writer.add_scalar('lr', lr_, iter_num)
        writer.add_scalar('loss/loss_seg', loss_seg, iter_num)
        writer.add_scalar('loss/loss_seg_dice', loss_seg_dice, iter_num)
        writer.add_scalar('loss/loss', loss, iter_num)
        logging.info('iteration %d : loss : %f, loss_seg : %f, loss_seg_dice : %f' % 
                        (iter_num, 
                        loss.item(),
                        loss_seg.item(),
                        loss_seg_dice.item())
                    )
        if iter_num % 50 == 0:
            image = volume_batch[0, 0:1, :, :, 20:61:10].permute(3,0,1,2).repeat(1,3,1,1)
            grid_image = make_grid(image, 5, normalize=True)
            writer.add_image('train/Image', grid_image, iter_num)

            outputs_soft = F.softmax(outputs, 1)
            image = outputs_soft[0, 1:2, :, :, 20:61:10].permute(3, 0, 1, 2).repeat(1, 3, 1, 1)
            grid_image = make_grid(image, 5, normalize=False)
            writer.add_image('train/Predicted_label', grid_image, iter_num)

            image = label_batch[0, :, :, 20:61:10].unsqueeze(0).permute(3, 0, 1, 2).repeat(1, 3, 1, 1)
            grid_image = make_grid(image, 5, normalize=False)
            writer.add_image('train/Groundtruth_label', grid_image, iter_num)

        ## change lr
        if iter_num % 2500 == 0:
            lr_ = base_lr * 0.1 ** (iter_num // 2500)
            for param_group in optimizer.param_groups:
                param_group['lr'] = lr_
        if iter_num % 500 == 0:
            save_mode_path = os.path.join(snapshot_path, 'iter_' + str(iter_num) + '.pth')
            torch.save(net.state_dict(), save_mode_path)
            logging.info("save model to {}".format(save_mode_path))

        if iter_num > max_iterations:
            break
        time1 = time.time()
    if iter_num > max_iterations:
        break
save_mode_path = os.path.join(snapshot_path, 'iter_'+str(max_iterations+1)+'.pth')
torch.save(net.state_dict(), save_mode_path)
logging.info("save model to {}".format(save_mode_path))
writer.close()
# Out:
# Namespace(base_lr=0.01, batch_size=8, deterministic=1, exp='vnet_supervisedonly_dp', gpu='0', max_iterations=6000, root_path='../../data/gz_dataset/segmented', seed=1337)
# total 32 samples
# total 8 samples
# 4 itertations per epoch
#   0%|                                        | 0/1501 [00:00<?, ?it/s]
# dice score (1-dice_loss): 0.540
# dice score (1-dice_loss): 0.129
# dice score (1-dice_loss): 0.089
# dice score (1-dice_loss): 0.039
# dicetotal:3.203
# iteration 1 : loss : 2.257948, loss_seg : 1.313094, loss_seg_dice : 3.202803
#
#
# dice score (1-dice_loss): 0.554
# dice score (1-dice_loss): 0.160
# dice score (1-dice_loss): 0.090
# dice score (1-dice_loss): 0.069
# dicetotal:3.127
# iteration 2 : loss : 2.214732, loss_seg : 1.302795, loss_seg_dice : 3.126670
#
#
# dice score (1-dice_loss): 0.559
# dice score (1-dice_loss): 0.091
# dice score (1-dice_loss): 0.052
# dice score (1-dice_loss): 0.051
# dicetotal:3.248
# iteration 3 : loss : 2.263865, loss_seg : 1.280093, loss_seg_dice : 3.247638
#
#
# dice score (1-dice_loss): 0.556
# dice score (1-dice_loss): 0.088
# dice score (1-dice_loss): 0.120
# dice score (1-dice_loss): 0.079
# dicetotal:3.157
# iteration 4 : loss : 2.240952, loss_seg : 1.325278, loss_seg_dice : 3.156627
#   0%|                              | 1/1501 [00:18<7:30:22, 18.01s/it]
# dice score (1-dice_loss): 0.583
# dice score (1-dice_loss): 0.111
# dice score (1-dice_loss): 0.139
# dice score (1-dice_loss): 0.084
# dicetotal:3.083
# iteration 5 : loss : 2.196725, loss_seg : 1.310904, loss_seg_dice : 3.082546
#
#
# dice score (1-dice_loss): 0.653
# dice score (1-dice_loss): 0.107
# dice score (1-dice_loss): 0.111
# dice score (1-dice_loss): 0.092
# dicetotal:3.038
# iteration 6 : loss : 2.105874, loss_seg : 1.174239, loss_seg_dice : 3.037508
#
#
# dice score (1-dice_loss): 0.539
# dice score (1-dice_loss): 0.068
# dice score (1-dice_loss): 0.043
# dice score (1-dice_loss): 0.014
# dicetotal:3.336
# iteration 7 : loss : 2.319148, loss_seg : 1.302043, loss_seg_dice : 3.336252
#
#
# dice score (1-dice_loss): 0.631
# dice score (1-dice_loss): 0.101
# dice score (1-dice_loss): 0.075
# dice score (1-dice_loss): 0.034
# dicetotal:3.159
# iteration 8 : loss : 2.160141, loss_seg : 1.161128, loss_seg_dice : 3.159154
#   0%|                              | 2/1501 [00:35<7:22:32, 17.71s/it]
# dice score (1-dice_loss): 0.651
# dice score (1-dice_loss): 0.091
# dice score (1-dice_loss): 0.090
# dice score (1-dice_loss): 0.036
# dicetotal:3.133
# iteration 9 : loss : 2.121930, loss_seg : 1.110983, loss_seg_dice : 3.132876
#
#
# dice score (1-dice_loss): 0.677
# dice score (1-dice_loss): 0.136
# dice score (1-dice_loss): 0.141
# dice score (1-dice_loss): 0.080
# dicetotal:2.966
# iteration 10 : loss : 2.073006, loss_seg : 1.180208, loss_seg_dice : 2.965803
#
#
# dice score (1-dice_loss): 0.662
# dice score (1-dice_loss): 0.115
# dice score (1-dice_loss): 0.158
# dice score (1-dice_loss): 0.068
# dicetotal:2.998
# iteration 11 : loss : 2.104680, loss_seg : 1.211589, loss_seg_dice : 2.997772
#
#
# dice score (1-dice_loss): 0.738
# dice score (1-dice_loss): 0.123
# dice score (1-dice_loss): 0.128
# dice score (1-dice_loss): 0.050
# dicetotal:2.962
# iteration 12 : loss : 2.008264, loss_seg : 1.054541, loss_seg_dice : 2.961987
#   0%|                              | 3/1501 [00:53<7:28:56, 17.98s/it]
# dice score (1-dice_loss): 0.768
# dice score (1-dice_loss): 0.097
# dice score (1-dice_loss): 0.087
# dice score (1-dice_loss): 0.044
# dicetotal:3.004
# iteration 13 : loss : 1.985029, loss_seg : 0.965817, loss_seg_dice : 3.004241
#
#
# dice score (1-dice_loss): 0.793
# dice score (1-dice_loss): 0.127
# dice score (1-dice_loss): 0.149
# dice score (1-dice_loss): 0.076
# dicetotal:2.855
# iteration 14 : loss : 1.935135, loss_seg : 1.015123, loss_seg_dice : 2.855146
#
#
# dice score (1-dice_loss): 0.800
# dice score (1-dice_loss): 0.132
# dice score (1-dice_loss): 0.087
# dice score (1-dice_loss): 0.096
# dicetotal:2.886
# iteration 15 : loss : 1.932667, loss_seg : 0.979478, loss_seg_dice : 2.885857
#
#
# dice score (1-dice_loss): 0.813
# dice score (1-dice_loss): 0.137
# dice score (1-dice_loss): 0.103
# dice score (1-dice_loss): 0.059
# dicetotal:2.888
# iteration 16 : loss : 1.925942, loss_seg : 0.963639, loss_seg_dice : 2.888245
#   0%|                              | 4/1501 [01:11<7:27:21, 17.93s/it]
# dice score (1-dice_loss): 0.830
# dice score (1-dice_loss): 0.110
# dice score (1-dice_loss): 0.098
# dice score (1-dice_loss): 0.045
# dicetotal:2.917
# iteration 17 : loss : 1.885141, loss_seg : 0.853171, loss_seg_dice : 2.917110
#
#
# dice score (1-dice_loss): 0.810
# dice score (1-dice_loss): 0.124
# dice score (1-dice_loss): 0.130
# dice score (1-dice_loss): 0.057
# dicetotal:2.878
# iteration 18 : loss : 1.909176, loss_seg : 0.940299, loss_seg_dice : 2.878052
#
#
# dice score (1-dice_loss): 0.852
# dice score (1-dice_loss): 0.125
# dice score (1-dice_loss): 0.142
# dice score (1-dice_loss): 0.063
# dicetotal:2.819
# iteration 19 : loss : 1.861834, loss_seg : 0.905165, loss_seg_dice : 2.818502
#
#
# dice score (1-dice_loss): 0.878
# dice score (1-dice_loss): 0.165
# dice score (1-dice_loss): 0.123
# dice score (1-dice_loss): 0.089
# dicetotal:2.745
# iteration 20 : loss : 1.879081, loss_seg : 1.012822, loss_seg_dice : 2.745340
#   0%|                              | 5/1501 [01:31<7:45:09, 18.66s/it]
# dice score (1-dice_loss): 0.869
# dice score (1-dice_loss): 0.137
# dice score (1-dice_loss): 0.096
# dice score (1-dice_loss): 0.073
# dicetotal:2.825
# iteration 21 : loss : 1.837249, loss_seg : 0.849777, loss_seg_dice : 2.824720
#
#
# dice score (1-dice_loss): 0.874
# dice score (1-dice_loss): 0.074
# dice score (1-dice_loss): 0.126
# dice score (1-dice_loss): 0.051
# dicetotal:2.874
# iteration 22 : loss : 1.850189, loss_seg : 0.826504, loss_seg_dice : 2.873874
#
#
# dice score (1-dice_loss): 0.915
# dice score (1-dice_loss): 0.136
# dice score (1-dice_loss): 0.081
# dice score (1-dice_loss): 0.061
# dicetotal:2.806
# iteration 23 : loss : 1.897282, loss_seg : 0.988288, loss_seg_dice : 2.806275
#
#
# dice score (1-dice_loss): 0.903
# dice score (1-dice_loss): 0.160
# dice score (1-dice_loss): 0.132
# dice score (1-dice_loss): 0.096
# dicetotal:2.709
# iteration 24 : loss : 1.867213, loss_seg : 1.025673, loss_seg_dice : 2.708753
#   0%|                              | 6/1501 [01:50<7:47:02, 18.74s/it]
# dice score (1-dice_loss): 0.904
# dice score (1-dice_loss): 0.105
# dice score (1-dice_loss): 0.137
# dice score (1-dice_loss): 0.060
# dicetotal:2.794
# iteration 25 : loss : 1.869595, loss_seg : 0.945157, loss_seg_dice : 2.794033
#
#
# dice score (1-dice_loss): 0.905
# dice score (1-dice_loss): 0.134
# dice score (1-dice_loss): 0.121
# dice score (1-dice_loss): 0.080
# dicetotal:2.760
# iteration 26 : loss : 1.854693, loss_seg : 0.949564, loss_seg_dice : 2.759821
#
#
# dice score (1-dice_loss): 0.910
# dice score (1-dice_loss): 0.134
# dice score (1-dice_loss): 0.139
# dice score (1-dice_loss): 0.111
# dicetotal:2.706
# iteration 27 : loss : 1.838866, loss_seg : 0.972048, loss_seg_dice : 2.705684
#
#
# dice score (1-dice_loss): 0.929
# dice score (1-dice_loss): 0.129
# dice score (1-dice_loss): 0.153
# dice score (1-dice_loss): 0.066
# dicetotal:2.723
# iteration 28 : loss : 1.773875, loss_seg : 0.825055, loss_seg_dice : 2.722695
#   0%|▏                             | 7/1501 [02:09<7:50:10, 18.88s/it]
# dice score (1-dice_loss): 0.923
# dice score (1-dice_loss): 0.139
# dice score (1-dice_loss): 0.113
# dice score (1-dice_loss): 0.078
# dicetotal:2.747
# iteration 29 : loss : 1.760418, loss_seg : 0.773735, loss_seg_dice : 2.747101
#
#
# dice score (1-dice_loss): 0.914
# dice score (1-dice_loss): 0.136
# dice score (1-dice_loss): 0.091
# dice score (1-dice_loss): 0.108
# dicetotal:2.751
# iteration 30 : loss : 1.785584, loss_seg : 0.820130, loss_seg_dice : 2.751037
#
#
# dice score (1-dice_loss): 0.932
# dice score (1-dice_loss): 0.148
# dice score (1-dice_loss): 0.120
# dice score (1-dice_loss): 0.077
# dicetotal:2.723
# iteration 31 : loss : 1.838471, loss_seg : 0.953769, loss_seg_dice : 2.723173
#
#
# dice score (1-dice_loss): 0.922
# dice score (1-dice_loss): 0.107
# dice score (1-dice_loss): 0.155
# dice score (1-dice_loss): 0.045
# dicetotal:2.771
# iteration 32 : loss : 1.705591, loss_seg : 0.640347, loss_seg_dice : 2.770835
#   1%|▏                             | 8/1501 [02:29<7:52:19, 18.98s/it]
# dice score (1-dice_loss): 0.942
# dice score (1-dice_loss): 0.143
# dice score (1-dice_loss): 0.145
# dice score (1-dice_loss): 0.092
# dicetotal:2.678
# iteration 33 : loss : 1.714538, loss_seg : 0.751058, loss_seg_dice : 2.678019
#
#
# dice score (1-dice_loss): 0.934
# dice score (1-dice_loss): 0.178
# dice score (1-dice_loss): 0.163
# dice score (1-dice_loss): 0.120
# dicetotal:2.606
# iteration 34 : loss : 1.761359, loss_seg : 0.917125, loss_seg_dice : 2.605594
#
#
# dice score (1-dice_loss): 0.929
# dice score (1-dice_loss): 0.185
# dice score (1-dice_loss): 0.172
# dice score (1-dice_loss): 0.124
# dicetotal:2.590
# iteration 35 : loss : 1.784278, loss_seg : 0.978127, loss_seg_dice : 2.590428
#
#
# dice score (1-dice_loss): 0.945
# dice score (1-dice_loss): 0.100
# dice score (1-dice_loss): 0.162
# dice score (1-dice_loss): 0.071
# dicetotal:2.722
# iteration 36 : loss : 1.681069, loss_seg : 0.639679, loss_seg_dice : 2.722458
#   1%|▏                             | 9/1501 [02:48<7:51:08, 18.95s/it]
# dice score (1-dice_loss): 0.934
# dice score (1-dice_loss): 0.148
# dice score (1-dice_loss): 0.150
# dice score (1-dice_loss): 0.101
# dicetotal:2.667
# iteration 37 : loss : 1.767685, loss_seg : 0.868336, loss_seg_dice : 2.667035
#
#
# dice score (1-dice_loss): 0.940
# dice score (1-dice_loss): 0.158
# dice score (1-dice_loss): 0.182
# dice score (1-dice_loss): 0.089
# dicetotal:2.631
# iteration 38 : loss : 1.731815, loss_seg : 0.832794, loss_seg_dice : 2.630836
#
#
# dice score (1-dice_loss): 0.946
# dice score (1-dice_loss): 0.153
# dice score (1-dice_loss): 0.109
# dice score (1-dice_loss): 0.121
# dicetotal:2.672
# iteration 39 : loss : 1.697113, loss_seg : 0.722564, loss_seg_dice : 2.671662
#
#
# dice score (1-dice_loss): 0.946
# dice score (1-dice_loss): 0.156
# dice score (1-dice_loss): 0.176
# dice score (1-dice_loss): 0.109
# dicetotal:2.613
# iteration 40 : loss : 1.651381, loss_seg : 0.689500, loss_seg_dice : 2.613262
#   1%|▏                            | 10/1501 [03:06<7:49:15, 18.88s/it]
# dice score (1-dice_loss): 0.940
# dice score (1-dice_loss): 0.186
# dice score (1-dice_loss): 0.123
# dice score (1-dice_loss): 0.072
# dicetotal:2.679
# iteration 41 : loss : 1.663697, loss_seg : 0.648404, loss_seg_dice : 2.678990
#
#
# dice score (1-dice_loss): 0.950
# dice score (1-dice_loss): 0.161
# dice score (1-dice_loss): 0.162
# dice score (1-dice_loss): 0.121
# dicetotal:2.606
# iteration 42 : loss : 1.672343, loss_seg : 0.738194, loss_seg_dice : 2.606492
#
#
# dice score (1-dice_loss): 0.940
# dice score (1-dice_loss): 0.186
# dice score (1-dice_loss): 0.172
# dice score (1-dice_loss): 0.120
# dicetotal:2.581
# iteration 43 : loss : 1.656886, loss_seg : 0.732456, loss_seg_dice : 2.581315
#
#
# dice score (1-dice_loss): 0.948
# dice score (1-dice_loss): 0.146
# dice score (1-dice_loss): 0.176
# dice score (1-dice_loss): 0.092
# dicetotal:2.638
# iteration 44 : loss : 1.641696, loss_seg : 0.644998, loss_seg_dice : 2.638395
#   1%|▏                            | 11/1501 [03:25<7:49:08, 18.89s/it]
# dice score (1-dice_loss): 0.947
# dice score (1-dice_loss): 0.212
# dice score (1-dice_loss): 0.164
# dice score (1-dice_loss): 0.138
# dicetotal:2.539
# iteration 45 : loss : 1.696245, loss_seg : 0.853304, loss_seg_dice : 2.539186
#
#
# dice score (1-dice_loss): 0.948
# dice score (1-dice_loss): 0.186
# dice score (1-dice_loss): 0.207
# dice score (1-dice_loss): 0.083
# dicetotal:2.576
# iteration 46 : loss : 1.583883, loss_seg : 0.591458, loss_seg_dice : 2.576308
#
#
# dice score (1-dice_loss): 0.953
# dice score (1-dice_loss): 0.188
# dice score (1-dice_loss): 0.207
# dice score (1-dice_loss): 0.105
# dicetotal:2.546
# iteration 47 : loss : 1.574395, loss_seg : 0.602296, loss_seg_dice : 2.546494
#
#
# dice score (1-dice_loss): 0.931
# dice score (1-dice_loss): 0.181
# dice score (1-dice_loss): 0.202
# dice score (1-dice_loss): 0.108
# dicetotal:2.578
# iteration 48 : loss : 1.696327, loss_seg : 0.814786, loss_seg_dice : 2.577869
#   1%|▏                            | 12/1501 [03:43<7:42:15, 18.63s/it]
# dice score (1-dice_loss): 0.940
# dice score (1-dice_loss): 0.122
# dice score (1-dice_loss): 0.224
# dice score (1-dice_loss): 0.098
# dicetotal:2.616
# iteration 49 : loss : 1.627248, loss_seg : 0.638042, loss_seg_dice : 2.616455
#
#
# dice score (1-dice_loss): 0.945
# dice score (1-dice_loss): 0.212
# dice score (1-dice_loss): 0.178
# dice score (1-dice_loss): 0.097
# dicetotal:2.568
# iteration 50 : loss : 1.611389, loss_seg : 0.654633, loss_seg_dice : 2.568145
#
#
# dice score (1-dice_loss): 0.941
# dice score (1-dice_loss): 0.208
# dice score (1-dice_loss): 0.138
# dice score (1-dice_loss): 0.137
# dicetotal:2.576
# iteration 51 : loss : 1.649519, loss_seg : 0.723225, loss_seg_dice : 2.575814
#
#
# dice score (1-dice_loss): 0.946
# dice score (1-dice_loss): 0.207
# dice score (1-dice_loss): 0.236
# dice score (1-dice_loss): 0.137
# dicetotal:2.474
# iteration 52 : loss : 1.597498, loss_seg : 0.721387, loss_seg_dice : 2.473608
#   1%|▎                            | 13/1501 [04:02<7:42:50, 18.66s/it]
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.229
# dice score (1-dice_loss): 0.164
# dice score (1-dice_loss): 0.107
# dicetotal:2.546
# iteration 53 : loss : 1.570725, loss_seg : 0.595841, loss_seg_dice : 2.545610
#
#
# dice score (1-dice_loss): 0.941
# dice score (1-dice_loss): 0.214
# dice score (1-dice_loss): 0.214
# dice score (1-dice_loss): 0.139
# dicetotal:2.491
# iteration 54 : loss : 1.605337, loss_seg : 0.719801, loss_seg_dice : 2.490873
#
#
# dice score (1-dice_loss): 0.958
# dice score (1-dice_loss): 0.226
# dice score (1-dice_loss): 0.252
# dice score (1-dice_loss): 0.150
# dicetotal:2.413
# iteration 55 : loss : 1.521501, loss_seg : 0.629577, loss_seg_dice : 2.413424
#
#
# dice score (1-dice_loss): 0.953
# dice score (1-dice_loss): 0.220
# dice score (1-dice_loss): 0.184
# dice score (1-dice_loss): 0.115
# dicetotal:2.529
# iteration 56 : loss : 1.651283, loss_seg : 0.774031, loss_seg_dice : 2.528535
#   1%|▎                            | 14/1501 [04:20<7:38:48, 18.51s/it]
# dice score (1-dice_loss): 0.945
# dice score (1-dice_loss): 0.204
# dice score (1-dice_loss): 0.205
# dice score (1-dice_loss): 0.113
# dicetotal:2.533
# iteration 57 : loss : 1.662702, loss_seg : 0.792528, loss_seg_dice : 2.532875
#
#
# dice score (1-dice_loss): 0.938
# dice score (1-dice_loss): 0.213
# dice score (1-dice_loss): 0.172
# dice score (1-dice_loss): 0.110
# dicetotal:2.566
# iteration 58 : loss : 1.665192, loss_seg : 0.764230, loss_seg_dice : 2.566154
#
#
# dice score (1-dice_loss): 0.950
# dice score (1-dice_loss): 0.128
# dice score (1-dice_loss): 0.174
# dice score (1-dice_loss): 0.036
# dicetotal:2.712
# iteration 59 : loss : 1.586596, loss_seg : 0.460980, loss_seg_dice : 2.712211
#
#
# dice score (1-dice_loss): 0.946
# dice score (1-dice_loss): 0.185
# dice score (1-dice_loss): 0.181
# dice score (1-dice_loss): 0.151
# dicetotal:2.537
# iteration 60 : loss : 1.607301, loss_seg : 0.678067, loss_seg_dice : 2.536535
#   1%|▎                            | 15/1501 [04:38<7:30:23, 18.19s/it]
# dice score (1-dice_loss): 0.947
# dice score (1-dice_loss): 0.162
# dice score (1-dice_loss): 0.192
# dice score (1-dice_loss): 0.099
# dicetotal:2.601
# iteration 61 : loss : 1.613734, loss_seg : 0.626716, loss_seg_dice : 2.600752
#
#
# dice score (1-dice_loss): 0.943
# dice score (1-dice_loss): 0.191
# dice score (1-dice_loss): 0.221
# dice score (1-dice_loss): 0.103
# dicetotal:2.542
# iteration 62 : loss : 1.640209, loss_seg : 0.738575, loss_seg_dice : 2.541844
#
#
# dice score (1-dice_loss): 0.948
# dice score (1-dice_loss): 0.251
# dice score (1-dice_loss): 0.103
# dice score (1-dice_loss): 0.144
# dicetotal:2.554
# iteration 63 : loss : 1.583109, loss_seg : 0.612640, loss_seg_dice : 2.553577
#
#
# dice score (1-dice_loss): 0.950
# dice score (1-dice_loss): 0.238
# dice score (1-dice_loss): 0.209
# dice score (1-dice_loss): 0.142
# dicetotal:2.460
# iteration 64 : loss : 1.598086, loss_seg : 0.735733, loss_seg_dice : 2.460439
#   1%|▎                            | 16/1501 [04:57<7:36:14, 18.43s/it]
# dice score (1-dice_loss): 0.943
# dice score (1-dice_loss): 0.133
# dice score (1-dice_loss): 0.252
# dice score (1-dice_loss): 0.094
# dicetotal:2.578
# iteration 65 : loss : 1.606892, loss_seg : 0.635660, loss_seg_dice : 2.578124
#
#
# dice score (1-dice_loss): 0.952
# dice score (1-dice_loss): 0.239
# dice score (1-dice_loss): 0.192
# dice score (1-dice_loss): 0.076
# dicetotal:2.541
# iteration 66 : loss : 1.556052, loss_seg : 0.571063, loss_seg_dice : 2.541040
#
#
# dice score (1-dice_loss): 0.941
# dice score (1-dice_loss): 0.205
# dice score (1-dice_loss): 0.191
# dice score (1-dice_loss): 0.131
# dicetotal:2.532
# iteration 67 : loss : 1.621896, loss_seg : 0.711784, loss_seg_dice : 2.532008
#
#
# dice score (1-dice_loss): 0.950
# dice score (1-dice_loss): 0.226
# dice score (1-dice_loss): 0.157
# dice score (1-dice_loss): 0.103
# dicetotal:2.564
# iteration 68 : loss : 1.678706, loss_seg : 0.792923, loss_seg_dice : 2.564488
#   1%|▎                            | 17/1501 [05:15<7:32:32, 18.30s/it]
# dice score (1-dice_loss): 0.948
# dice score (1-dice_loss): 0.159
# dice score (1-dice_loss): 0.232
# dice score (1-dice_loss): 0.090
# dicetotal:2.571
# iteration 69 : loss : 1.618711, loss_seg : 0.666437, loss_seg_dice : 2.570985
#
#
# dice score (1-dice_loss): 0.950
# dice score (1-dice_loss): 0.235
# dice score (1-dice_loss): 0.179
# dice score (1-dice_loss): 0.105
# dicetotal:2.531
# iteration 70 : loss : 1.569209, loss_seg : 0.607507, loss_seg_dice : 2.530910
#
#
# dice score (1-dice_loss): 0.950
# dice score (1-dice_loss): 0.226
# dice score (1-dice_loss): 0.217
# dice score (1-dice_loss): 0.140
# dicetotal:2.468
# iteration 71 : loss : 1.617269, loss_seg : 0.766442, loss_seg_dice : 2.468096
#
#
# dice score (1-dice_loss): 0.957
# dice score (1-dice_loss): 0.243
# dice score (1-dice_loss): 0.245
# dice score (1-dice_loss): 0.138
# dicetotal:2.418
# iteration 72 : loss : 1.576078, loss_seg : 0.734422, loss_seg_dice : 2.417734
#   1%|▎                            | 18/1501 [05:33<7:30:36, 18.23s/it]
# dice score (1-dice_loss): 0.947
# dice score (1-dice_loss): 0.216
# dice score (1-dice_loss): 0.138
# dice score (1-dice_loss): 0.123
# dicetotal:2.577
# iteration 73 : loss : 1.784396, loss_seg : 0.991990, loss_seg_dice : 2.576802
#
#
# dice score (1-dice_loss): 0.954
# dice score (1-dice_loss): 0.194
# dice score (1-dice_loss): 0.233
# dice score (1-dice_loss): 0.117
# dicetotal:2.502
# iteration 74 : loss : 1.521703, loss_seg : 0.541709, loss_seg_dice : 2.501696
#
#
# dice score (1-dice_loss): 0.950
# dice score (1-dice_loss): 0.265
# dice score (1-dice_loss): 0.209
# dice score (1-dice_loss): 0.158
# dicetotal:2.419
# iteration 75 : loss : 1.627664, loss_seg : 0.836066, loss_seg_dice : 2.419262
#
#
# dice score (1-dice_loss): 0.956
# dice score (1-dice_loss): 0.205
# dice score (1-dice_loss): 0.205
# dice score (1-dice_loss): 0.108
# dicetotal:2.526
# iteration 76 : loss : 1.563999, loss_seg : 0.602255, loss_seg_dice : 2.525744
#   1%|▎                            | 19/1501 [05:51<7:29:52, 18.21s/it]
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.237
# dice score (1-dice_loss): 0.202
# dice score (1-dice_loss): 0.092
# dicetotal:2.513
# iteration 77 : loss : 1.517677, loss_seg : 0.522726, loss_seg_dice : 2.512627
#
#
# dice score (1-dice_loss): 0.942
# dice score (1-dice_loss): 0.130
# dice score (1-dice_loss): 0.184
# dice score (1-dice_loss): 0.105
# dicetotal:2.639
# iteration 78 : loss : 1.673054, loss_seg : 0.707164, loss_seg_dice : 2.638943
#
#
# dice score (1-dice_loss): 0.950
# dice score (1-dice_loss): 0.225
# dice score (1-dice_loss): 0.167
# dice score (1-dice_loss): 0.134
# dicetotal:2.524
# iteration 79 : loss : 1.568722, loss_seg : 0.613205, loss_seg_dice : 2.524240
#
#
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.242
# dice score (1-dice_loss): 0.201
# dice score (1-dice_loss): 0.150
# dicetotal:2.452
# iteration 80 : loss : 1.557773, loss_seg : 0.663526, loss_seg_dice : 2.452020
#   1%|▍                            | 20/1501 [06:09<7:26:17, 18.08s/it]
# dice score (1-dice_loss): 0.956
# dice score (1-dice_loss): 0.143
# dice score (1-dice_loss): 0.204
# dice score (1-dice_loss): 0.119
# dicetotal:2.578
# iteration 81 : loss : 1.562473, loss_seg : 0.547034, loss_seg_dice : 2.577912
#
#
# dice score (1-dice_loss): 0.949
# dice score (1-dice_loss): 0.206
# dice score (1-dice_loss): 0.177
# dice score (1-dice_loss): 0.114
# dicetotal:2.554
# iteration 82 : loss : 1.579018, loss_seg : 0.603581, loss_seg_dice : 2.554454
#
#
# dice score (1-dice_loss): 0.944
# dice score (1-dice_loss): 0.266
# dice score (1-dice_loss): 0.195
# dice score (1-dice_loss): 0.119
# dicetotal:2.476
# iteration 83 : loss : 1.683440, loss_seg : 0.890962, loss_seg_dice : 2.475919
#
#
# dice score (1-dice_loss): 0.952
# dice score (1-dice_loss): 0.170
# dice score (1-dice_loss): 0.224
# dice score (1-dice_loss): 0.148
# dicetotal:2.507
# iteration 84 : loss : 1.567751, loss_seg : 0.628741, loss_seg_dice : 2.506760
#   1%|▍                            | 21/1501 [06:27<7:32:25, 18.34s/it]
# dice score (1-dice_loss): 0.948
# dice score (1-dice_loss): 0.173
# dice score (1-dice_loss): 0.231
# dice score (1-dice_loss): 0.117
# dicetotal:2.531
# iteration 85 : loss : 1.556681, loss_seg : 0.582752, loss_seg_dice : 2.530610
#
#
# dice score (1-dice_loss): 0.947
# dice score (1-dice_loss): 0.223
# dice score (1-dice_loss): 0.201
# dice score (1-dice_loss): 0.121
# dicetotal:2.508
# iteration 86 : loss : 1.632840, loss_seg : 0.757917, loss_seg_dice : 2.507764
#
#
# dice score (1-dice_loss): 0.948
# dice score (1-dice_loss): 0.237
# dice score (1-dice_loss): 0.208
# dice score (1-dice_loss): 0.121
# dicetotal:2.486
# iteration 87 : loss : 1.653295, loss_seg : 0.820760, loss_seg_dice : 2.485830
#
#
# dice score (1-dice_loss): 0.956
# dice score (1-dice_loss): 0.229
# dice score (1-dice_loss): 0.202
# dice score (1-dice_loss): 0.117
# dicetotal:2.495
# iteration 88 : loss : 1.510851, loss_seg : 0.526518, loss_seg_dice : 2.495184
#   1%|▍                            | 22/1501 [06:46<7:30:20, 18.27s/it]
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.224
# dice score (1-dice_loss): 0.225
# dice score (1-dice_loss): 0.136
# dicetotal:2.460
# iteration 89 : loss : 1.563076, loss_seg : 0.666001, loss_seg_dice : 2.460150
#
#
# dice score (1-dice_loss): 0.953
# dice score (1-dice_loss): 0.212
# dice score (1-dice_loss): 0.218
# dice score (1-dice_loss): 0.104
# dicetotal:2.514
# iteration 90 : loss : 1.548116, loss_seg : 0.582288, loss_seg_dice : 2.513943
#
#
# dice score (1-dice_loss): 0.958
# dice score (1-dice_loss): 0.245
# dice score (1-dice_loss): 0.227
# dice score (1-dice_loss): 0.170
# dicetotal:2.399
# iteration 91 : loss : 1.506752, loss_seg : 0.614171, loss_seg_dice : 2.399333
#
#
# dice score (1-dice_loss): 0.951
# dice score (1-dice_loss): 0.191
# dice score (1-dice_loss): 0.189
# dice score (1-dice_loss): 0.133
# dicetotal:2.535
# iteration 92 : loss : 1.615076, loss_seg : 0.694883, loss_seg_dice : 2.535270
#   2%|▍                            | 23/1501 [07:05<7:41:11, 18.72s/it]
# dice score (1-dice_loss): 0.937
# dice score (1-dice_loss): 0.213
# dice score (1-dice_loss): 0.181
# dice score (1-dice_loss): 0.131
# dicetotal:2.537
# iteration 93 : loss : 1.634318, loss_seg : 0.731739, loss_seg_dice : 2.536896
#
#
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.206
# dice score (1-dice_loss): 0.176
# dice score (1-dice_loss): 0.122
# dicetotal:2.540
# iteration 94 : loss : 1.555013, loss_seg : 0.569845, loss_seg_dice : 2.540180
#
#
# dice score (1-dice_loss): 0.952
# dice score (1-dice_loss): 0.254
# dice score (1-dice_loss): 0.238
# dice score (1-dice_loss): 0.114
# dicetotal:2.441
# iteration 95 : loss : 1.603638, loss_seg : 0.766409, loss_seg_dice : 2.440866
#
#
# dice score (1-dice_loss): 0.954
# dice score (1-dice_loss): 0.263
# dice score (1-dice_loss): 0.192
# dice score (1-dice_loss): 0.145
# dicetotal:2.446
# iteration 96 : loss : 1.590359, loss_seg : 0.734439, loss_seg_dice : 2.446280
#   2%|▍                            | 24/1501 [07:24<7:38:49, 18.64s/it]
# dice score (1-dice_loss): 0.948
# dice score (1-dice_loss): 0.245
# dice score (1-dice_loss): 0.222
# dice score (1-dice_loss): 0.145
# dicetotal:2.441
# iteration 97 : loss : 1.612501, loss_seg : 0.784234, loss_seg_dice : 2.440768
#
#
# dice score (1-dice_loss): 0.957
# dice score (1-dice_loss): 0.254
# dice score (1-dice_loss): 0.169
# dice score (1-dice_loss): 0.148
# dicetotal:2.472
# iteration 98 : loss : 1.529820, loss_seg : 0.587793, loss_seg_dice : 2.471847
#
#
# dice score (1-dice_loss): 0.956
# dice score (1-dice_loss): 0.198
# dice score (1-dice_loss): 0.184
# dice score (1-dice_loss): 0.105
# dicetotal:2.557
# iteration 99 : loss : 1.594054, loss_seg : 0.631447, loss_seg_dice : 2.556660
#
#
# dice score (1-dice_loss): 0.954
# dice score (1-dice_loss): 0.257
# dice score (1-dice_loss): 0.205
# dice score (1-dice_loss): 0.145
# dicetotal:2.440
# iteration 100 : loss : 1.553231, loss_seg : 0.666799, loss_seg_dice : 2.439664
#   2%|▍                            | 25/1501 [07:41<7:30:56, 18.33s/it]
# dice score (1-dice_loss): 0.951
# dice score (1-dice_loss): 0.235
# dice score (1-dice_loss): 0.235
# dice score (1-dice_loss): 0.149
# dicetotal:2.430
# iteration 101 : loss : 1.577859, loss_seg : 0.725695, loss_seg_dice : 2.430022
#
#
# dice score (1-dice_loss): 0.957
# dice score (1-dice_loss): 0.216
# dice score (1-dice_loss): 0.237
# dice score (1-dice_loss): 0.135
# dicetotal:2.456
# iteration 102 : loss : 1.541284, loss_seg : 0.626924, loss_seg_dice : 2.455644
#
#
# dice score (1-dice_loss): 0.951
# dice score (1-dice_loss): 0.197
# dice score (1-dice_loss): 0.190
# dice score (1-dice_loss): 0.128
# dicetotal:2.534
# iteration 103 : loss : 1.573956, loss_seg : 0.614035, loss_seg_dice : 2.533876
#
#
# dice score (1-dice_loss): 0.952
# dice score (1-dice_loss): 0.209
# dice score (1-dice_loss): 0.181
# dice score (1-dice_loss): 0.140
# dicetotal:2.517
# iteration 104 : loss : 1.618824, loss_seg : 0.720508, loss_seg_dice : 2.517142
#   2%|▌                            | 26/1501 [08:00<7:29:16, 18.28s/it]
# dice score (1-dice_loss): 0.948
# dice score (1-dice_loss): 0.227
# dice score (1-dice_loss): 0.202
# dice score (1-dice_loss): 0.103
# dicetotal:2.521
# iteration 105 : loss : 1.619523, loss_seg : 0.718333, loss_seg_dice : 2.520713
#
#
# dice score (1-dice_loss): 0.951
# dice score (1-dice_loss): 0.271
# dice score (1-dice_loss): 0.212
# dice score (1-dice_loss): 0.149
# dicetotal:2.416
# iteration 106 : loss : 1.608216, loss_seg : 0.799942, loss_seg_dice : 2.416489
#
#
# dice score (1-dice_loss): 0.952
# dice score (1-dice_loss): 0.214
# dice score (1-dice_loss): 0.231
# dice score (1-dice_loss): 0.132
# dicetotal:2.471
# iteration 107 : loss : 1.527017, loss_seg : 0.582547, loss_seg_dice : 2.471487
#
#
# dice score (1-dice_loss): 0.953
# dice score (1-dice_loss): 0.230
# dice score (1-dice_loss): 0.235
# dice score (1-dice_loss): 0.109
# dicetotal:2.473
# iteration 108 : loss : 1.527317, loss_seg : 0.581390, loss_seg_dice : 2.473245
#   2%|▌                            | 27/1501 [08:18<7:30:28, 18.34s/it]
# dice score (1-dice_loss): 0.953
# dice score (1-dice_loss): 0.262
# dice score (1-dice_loss): 0.230
# dice score (1-dice_loss): 0.115
# dicetotal:2.440
# iteration 109 : loss : 1.595357, loss_seg : 0.751019, loss_seg_dice : 2.439695
#
#
# dice score (1-dice_loss): 0.954
# dice score (1-dice_loss): 0.217
# dice score (1-dice_loss): 0.247
# dice score (1-dice_loss): 0.116
# dicetotal:2.466
# iteration 110 : loss : 1.544587, loss_seg : 0.623430, loss_seg_dice : 2.465744
#
#
# dice score (1-dice_loss): 0.952
# dice score (1-dice_loss): 0.262
# dice score (1-dice_loss): 0.160
# dice score (1-dice_loss): 0.138
# dicetotal:2.487
# iteration 111 : loss : 1.553702, loss_seg : 0.620117, loss_seg_dice : 2.487287
#
#
# dice score (1-dice_loss): 0.959
# dice score (1-dice_loss): 0.227
# dice score (1-dice_loss): 0.223
# dice score (1-dice_loss): 0.123
# dicetotal:2.468
# iteration 112 : loss : 1.530569, loss_seg : 0.593230, loss_seg_dice : 2.467908
#   2%|▌                            | 28/1501 [08:36<7:31:03, 18.37s/it]
# dice score (1-dice_loss): 0.958
# dice score (1-dice_loss): 0.236
# dice score (1-dice_loss): 0.117
# dice score (1-dice_loss): 0.149
# dicetotal:2.540
# iteration 113 : loss : 1.517282, loss_seg : 0.494782, loss_seg_dice : 2.539782
#
#
# dice score (1-dice_loss): 0.944
# dice score (1-dice_loss): 0.253
# dice score (1-dice_loss): 0.226
# dice score (1-dice_loss): 0.142
# dicetotal:2.435
# iteration 114 : loss : 1.560233, loss_seg : 0.685407, loss_seg_dice : 2.435059
#
#
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.261
# dice score (1-dice_loss): 0.205
# dice score (1-dice_loss): 0.131
# dicetotal:2.448
# iteration 115 : loss : 1.553919, loss_seg : 0.659406, loss_seg_dice : 2.448432
#
#
# dice score (1-dice_loss): 0.953
# dice score (1-dice_loss): 0.232
# dice score (1-dice_loss): 0.228
# dice score (1-dice_loss): 0.146
# dicetotal:2.442
# iteration 116 : loss : 1.552012, loss_seg : 0.662468, loss_seg_dice : 2.441557
#   2%|▌                            | 29/1501 [08:55<7:35:22, 18.56s/it]
# dice score (1-dice_loss): 0.952
# dice score (1-dice_loss): 0.247
# dice score (1-dice_loss): 0.185
# dice score (1-dice_loss): 0.129
# dicetotal:2.487
# iteration 117 : loss : 1.656633, loss_seg : 0.825898, loss_seg_dice : 2.487369
#
#
# dice score (1-dice_loss): 0.949
# dice score (1-dice_loss): 0.222
# dice score (1-dice_loss): 0.226
# dice score (1-dice_loss): 0.146
# dicetotal:2.457
# iteration 118 : loss : 1.608306, loss_seg : 0.759379, loss_seg_dice : 2.457234
#
#
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.161
# dice score (1-dice_loss): 0.235
# dice score (1-dice_loss): 0.123
# dicetotal:2.526
# iteration 119 : loss : 1.516741, loss_seg : 0.507798, loss_seg_dice : 2.525685
#
#
# dice score (1-dice_loss): 0.948
# dice score (1-dice_loss): 0.228
# dice score (1-dice_loss): 0.229
# dice score (1-dice_loss): 0.126
# dicetotal:2.468
# iteration 120 : loss : 1.538462, loss_seg : 0.608720, loss_seg_dice : 2.468203
#   2%|▌                            | 30/1501 [09:14<7:32:07, 18.44s/it]
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.267
# dice score (1-dice_loss): 0.182
# dice score (1-dice_loss): 0.144
# dicetotal:2.452
# iteration 121 : loss : 1.553482, loss_seg : 0.655037, loss_seg_dice : 2.451927
#
#
# dice score (1-dice_loss): 0.957
# dice score (1-dice_loss): 0.280
# dice score (1-dice_loss): 0.204
# dice score (1-dice_loss): 0.153
# dicetotal:2.406
# iteration 122 : loss : 1.538224, loss_seg : 0.670019, loss_seg_dice : 2.406429
#
#
# dice score (1-dice_loss): 0.956
# dice score (1-dice_loss): 0.243
# dice score (1-dice_loss): 0.205
# dice score (1-dice_loss): 0.166
# dicetotal:2.430
# iteration 123 : loss : 1.554012, loss_seg : 0.678519, loss_seg_dice : 2.429505
#
#
# dice score (1-dice_loss): 0.963
# dice score (1-dice_loss): 0.260
# dice score (1-dice_loss): 0.251
# dice score (1-dice_loss): 0.131
# dicetotal:2.395
# iteration 124 : loss : 1.466554, loss_seg : 0.538029, loss_seg_dice : 2.395079
#   2%|▌                            | 31/1501 [09:32<7:27:56, 18.28s/it]
# dice score (1-dice_loss): 0.953
# dice score (1-dice_loss): 0.271
# dice score (1-dice_loss): 0.124
# dice score (1-dice_loss): 0.159
# dicetotal:2.493
# iteration 125 : loss : 1.546836, loss_seg : 0.600827, loss_seg_dice : 2.492846
#
#
# dice score (1-dice_loss): 0.957
# dice score (1-dice_loss): 0.290
# dice score (1-dice_loss): 0.237
# dice score (1-dice_loss): 0.128
# dicetotal:2.390
# iteration 126 : loss : 1.565023, loss_seg : 0.740440, loss_seg_dice : 2.389606
#
#
# dice score (1-dice_loss): 0.962
# dice score (1-dice_loss): 0.299
# dice score (1-dice_loss): 0.196
# dice score (1-dice_loss): 0.176
# dicetotal:2.368
# iteration 127 : loss : 1.529861, loss_seg : 0.691765, loss_seg_dice : 2.367957
#
#
# dice score (1-dice_loss): 0.964
# dice score (1-dice_loss): 0.264
# dice score (1-dice_loss): 0.239
# dice score (1-dice_loss): 0.170
# dicetotal:2.364
# iteration 128 : loss : 1.472213, loss_seg : 0.580757, loss_seg_dice : 2.363668
#   2%|▌                            | 32/1501 [09:51<7:39:25, 18.76s/it]
# dice score (1-dice_loss): 0.954
# dice score (1-dice_loss): 0.224
# dice score (1-dice_loss): 0.241
# dice score (1-dice_loss): 0.093
# dicetotal:2.488
# iteration 129 : loss : 1.528501, loss_seg : 0.569381, loss_seg_dice : 2.487620
#
#
# dice score (1-dice_loss): 0.960
# dice score (1-dice_loss): 0.214
# dice score (1-dice_loss): 0.240
# dice score (1-dice_loss): 0.149
# dicetotal:2.436
# iteration 130 : loss : 1.573727, loss_seg : 0.711305, loss_seg_dice : 2.436150
#
#
# dice score (1-dice_loss): 0.957
# dice score (1-dice_loss): 0.214
# dice score (1-dice_loss): 0.205
# dice score (1-dice_loss): 0.150
# dicetotal:2.475
# iteration 131 : loss : 1.497503, loss_seg : 0.520051, loss_seg_dice : 2.474955
#
#
# dice score (1-dice_loss): 0.962
# dice score (1-dice_loss): 0.278
# dice score (1-dice_loss): 0.255
# dice score (1-dice_loss): 0.167
# dicetotal:2.338
# iteration 132 : loss : 1.511939, loss_seg : 0.685715, loss_seg_dice : 2.338162
#   2%|▋                            | 33/1501 [10:09<7:32:05, 18.48s/it]
# dice score (1-dice_loss): 0.964
# dice score (1-dice_loss): 0.284
# dice score (1-dice_loss): 0.262
# dice score (1-dice_loss): 0.188
# dicetotal:2.301
# iteration 133 : loss : 1.475803, loss_seg : 0.650351, loss_seg_dice : 2.301256
#
#
# dice score (1-dice_loss): 0.963
# dice score (1-dice_loss): 0.266
# dice score (1-dice_loss): 0.128
# dice score (1-dice_loss): 0.146
# dicetotal:2.496
# iteration 134 : loss : 1.483772, loss_seg : 0.471143, loss_seg_dice : 2.496401
#
#
# dice score (1-dice_loss): 0.952
# dice score (1-dice_loss): 0.190
# dice score (1-dice_loss): 0.235
# dice score (1-dice_loss): 0.112
# dicetotal:2.511
# iteration 135 : loss : 1.542563, loss_seg : 0.574596, loss_seg_dice : 2.510530
#
#
# dice score (1-dice_loss): 0.966
# dice score (1-dice_loss): 0.229
# dice score (1-dice_loss): 0.203
# dice score (1-dice_loss): 0.128
# dicetotal:2.474
# iteration 136 : loss : 1.448247, loss_seg : 0.421995, loss_seg_dice : 2.474499
#   2%|▋                            | 34/1501 [10:27<7:23:02, 18.12s/it]
# dice score (1-dice_loss): 0.964
# dice score (1-dice_loss): 0.263
# dice score (1-dice_loss): 0.230
# dice score (1-dice_loss): 0.134
# dicetotal:2.409
# iteration 137 : loss : 1.460216, loss_seg : 0.511075, loss_seg_dice : 2.409357
#
#
# dice score (1-dice_loss): 0.957
# dice score (1-dice_loss): 0.270
# dice score (1-dice_loss): 0.224
# dice score (1-dice_loss): 0.171
# dicetotal:2.378
# iteration 138 : loss : 1.562079, loss_seg : 0.746039, loss_seg_dice : 2.378119
#
#
# dice score (1-dice_loss): 0.960
# dice score (1-dice_loss): 0.285
# dice score (1-dice_loss): 0.230
# dice score (1-dice_loss): 0.158
# dicetotal:2.366
# iteration 139 : loss : 1.526917, loss_seg : 0.687738, loss_seg_dice : 2.366095
#
#
# dice score (1-dice_loss): 0.964
# dice score (1-dice_loss): 0.278
# dice score (1-dice_loss): 0.196
# dice score (1-dice_loss): 0.125
# dicetotal:2.437
# iteration 140 : loss : 1.549379, loss_seg : 0.661330, loss_seg_dice : 2.437428
#   2%|▋                            | 35/1501 [10:47<7:39:14, 18.80s/it]
# dice score (1-dice_loss): 0.959
# dice score (1-dice_loss): 0.274
# dice score (1-dice_loss): 0.241
# dice score (1-dice_loss): 0.125
# dicetotal:2.401
# iteration 141 : loss : 1.476279, loss_seg : 0.551422, loss_seg_dice : 2.401135
#
#
# dice score (1-dice_loss): 0.967
# dice score (1-dice_loss): 0.266
# dice score (1-dice_loss): 0.160
# dice score (1-dice_loss): 0.131
# dicetotal:2.475
# iteration 142 : loss : 1.491575, loss_seg : 0.507818, loss_seg_dice : 2.475332
#
#
# dice score (1-dice_loss): 0.962
# dice score (1-dice_loss): 0.290
# dice score (1-dice_loss): 0.247
# dice score (1-dice_loss): 0.167
# dicetotal:2.334
# iteration 143 : loss : 1.507487, loss_seg : 0.680601, loss_seg_dice : 2.334373
#
#
# dice score (1-dice_loss): 0.959
# dice score (1-dice_loss): 0.297
# dice score (1-dice_loss): 0.238
# dice score (1-dice_loss): 0.188
# dicetotal:2.317
# iteration 144 : loss : 1.565261, loss_seg : 0.813814, loss_seg_dice : 2.316708
#   2%|▋                            | 36/1501 [11:05<7:31:10, 18.48s/it]
# dice score (1-dice_loss): 0.954
# dice score (1-dice_loss): 0.310
# dice score (1-dice_loss): 0.173
# dice score (1-dice_loss): 0.144
# dicetotal:2.419
# iteration 145 : loss : 1.639607, loss_seg : 0.859790, loss_seg_dice : 2.419424
#
#
# dice score (1-dice_loss): 0.959
# dice score (1-dice_loss): 0.288
# dice score (1-dice_loss): 0.204
# dice score (1-dice_loss): 0.154
# dicetotal:2.395
# iteration 146 : loss : 1.490483, loss_seg : 0.586035, loss_seg_dice : 2.394931
#
#
# dice score (1-dice_loss): 0.959
# dice score (1-dice_loss): 0.273
# dice score (1-dice_loss): 0.237
# dice score (1-dice_loss): 0.162
# dicetotal:2.368
# iteration 147 : loss : 1.483927, loss_seg : 0.599447, loss_seg_dice : 2.368406
#
#
# dice score (1-dice_loss): 0.951
# dice score (1-dice_loss): 0.300
# dice score (1-dice_loss): 0.206
# dice score (1-dice_loss): 0.177
# dicetotal:2.366
# iteration 148 : loss : 1.554633, loss_seg : 0.742790, loss_seg_dice : 2.366476
#   2%|▋                            | 37/1501 [11:24<7:39:03, 18.81s/it]
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.133
# dice score (1-dice_loss): 0.220
# dice score (1-dice_loss): 0.100
# dicetotal:2.594
# iteration 149 : loss : 1.515759, loss_seg : 0.437803, loss_seg_dice : 2.593715
#
#
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.243
# dice score (1-dice_loss): 0.187
# dice score (1-dice_loss): 0.144
# dicetotal:2.471
# iteration 150 : loss : 1.519033, loss_seg : 0.567190, loss_seg_dice : 2.470875
#
#
# dice score (1-dice_loss): 0.959
# dice score (1-dice_loss): 0.257
# dice score (1-dice_loss): 0.213
# dice score (1-dice_loss): 0.117
# dicetotal:2.454
# iteration 151 : loss : 1.465649, loss_seg : 0.477575, loss_seg_dice : 2.453724
#
#
# dice score (1-dice_loss): 0.957
# dice score (1-dice_loss): 0.259
# dice score (1-dice_loss): 0.244
# dice score (1-dice_loss): 0.157
# dicetotal:2.384
# iteration 152 : loss : 1.494694, loss_seg : 0.605845, loss_seg_dice : 2.383543
#   3%|▋                            | 38/1501 [11:43<7:41:47, 18.94s/it]
# dice score (1-dice_loss): 0.957
# dice score (1-dice_loss): 0.290
# dice score (1-dice_loss): 0.195
# dice score (1-dice_loss): 0.137
# dicetotal:2.422
# iteration 153 : loss : 1.549272, loss_seg : 0.676458, loss_seg_dice : 2.422086
#
#
# dice score (1-dice_loss): 0.958
# dice score (1-dice_loss): 0.250
# dice score (1-dice_loss): 0.276
# dice score (1-dice_loss): 0.122
# dicetotal:2.394
# iteration 154 : loss : 1.462907, loss_seg : 0.531737, loss_seg_dice : 2.394078
#
#
# dice score (1-dice_loss): 0.961
# dice score (1-dice_loss): 0.231
# dice score (1-dice_loss): 0.175
# dice score (1-dice_loss): 0.136
# dicetotal:2.496
# iteration 155 : loss : 1.472414, loss_seg : 0.448617, loss_seg_dice : 2.496210
#
#
# dice score (1-dice_loss): 0.953
# dice score (1-dice_loss): 0.290
# dice score (1-dice_loss): 0.203
# dice score (1-dice_loss): 0.177
# dicetotal:2.377
# iteration 156 : loss : 1.561855, loss_seg : 0.746890, loss_seg_dice : 2.376820
#   3%|▊                            | 39/1501 [12:01<7:32:05, 18.55s/it]
# dice score (1-dice_loss): 0.958
# dice score (1-dice_loss): 0.241
# dice score (1-dice_loss): 0.221
# dice score (1-dice_loss): 0.139
# dicetotal:2.440
# iteration 157 : loss : 1.533304, loss_seg : 0.626399, loss_seg_dice : 2.440209
#
#
# dice score (1-dice_loss): 0.959
# dice score (1-dice_loss): 0.266
# dice score (1-dice_loss): 0.227
# dice score (1-dice_loss): 0.166
# dicetotal:2.382
# iteration 158 : loss : 1.485916, loss_seg : 0.590218, loss_seg_dice : 2.381615
#
#
# dice score (1-dice_loss): 0.958
# dice score (1-dice_loss): 0.212
# dice score (1-dice_loss): 0.253
# dice score (1-dice_loss): 0.136
# dicetotal:2.441
# iteration 159 : loss : 1.511815, loss_seg : 0.582672, loss_seg_dice : 2.440958
#
#
# dice score (1-dice_loss): 0.957
# dice score (1-dice_loss): 0.281
# dice score (1-dice_loss): 0.237
# dice score (1-dice_loss): 0.117
# dicetotal:2.408
# iteration 160 : loss : 1.591923, loss_seg : 0.776109, loss_seg_dice : 2.407737
#   3%|▊                            | 40/1501 [12:19<7:24:27, 18.25s/it]
# dice score (1-dice_loss): 0.959
# dice score (1-dice_loss): 0.323
# dice score (1-dice_loss): 0.212
# dice score (1-dice_loss): 0.189
# dicetotal:2.318
# iteration 161 : loss : 1.511130, loss_seg : 0.704627, loss_seg_dice : 2.317633
#
#
# dice score (1-dice_loss): 0.945
# dice score (1-dice_loss): 0.234
# dice score (1-dice_loss): 0.223
# dice score (1-dice_loss): 0.138
# dicetotal:2.461
# iteration 162 : loss : 1.574057, loss_seg : 0.687514, loss_seg_dice : 2.460600
#
#
# dice score (1-dice_loss): 0.952
# dice score (1-dice_loss): 0.272
# dice score (1-dice_loss): 0.225
# dice score (1-dice_loss): 0.136
# dicetotal:2.415
# iteration 163 : loss : 1.495351, loss_seg : 0.575498, loss_seg_dice : 2.415204
#
#
# dice score (1-dice_loss): 0.953
# dice score (1-dice_loss): 0.288
# dice score (1-dice_loss): 0.211
# dice score (1-dice_loss): 0.180
# dicetotal:2.368
# iteration 164 : loss : 1.522182, loss_seg : 0.676613, loss_seg_dice : 2.367751
#   3%|▊                            | 41/1501 [12:38<7:35:03, 18.70s/it]
# dice score (1-dice_loss): 0.958
# dice score (1-dice_loss): 0.267
# dice score (1-dice_loss): 0.235
# dice score (1-dice_loss): 0.111
# dicetotal:2.429
# iteration 165 : loss : 1.498385, loss_seg : 0.567394, loss_seg_dice : 2.429376
#
#
# dice score (1-dice_loss): 0.957
# dice score (1-dice_loss): 0.240
# dice score (1-dice_loss): 0.174
# dice score (1-dice_loss): 0.147
# dicetotal:2.482
# iteration 166 : loss : 1.492604, loss_seg : 0.503523, loss_seg_dice : 2.481684
#
#
# dice score (1-dice_loss): 0.951
# dice score (1-dice_loss): 0.278
# dice score (1-dice_loss): 0.237
# dice score (1-dice_loss): 0.148
# dicetotal:2.386
# iteration 167 : loss : 1.546776, loss_seg : 0.707633, loss_seg_dice : 2.385919
#
#
# dice score (1-dice_loss): 0.961
# dice score (1-dice_loss): 0.321
# dice score (1-dice_loss): 0.242
# dice score (1-dice_loss): 0.180
# dicetotal:2.295
# iteration 168 : loss : 1.470169, loss_seg : 0.645052, loss_seg_dice : 2.295285
#   3%|▊                            | 42/1501 [12:58<7:44:28, 19.10s/it]
# dice score (1-dice_loss): 0.959
# dice score (1-dice_loss): 0.236
# dice score (1-dice_loss): 0.270
# dice score (1-dice_loss): 0.138
# dicetotal:2.397
# iteration 169 : loss : 1.457723, loss_seg : 0.518232, loss_seg_dice : 2.397214
#
#
# dice score (1-dice_loss): 0.959
# dice score (1-dice_loss): 0.247
# dice score (1-dice_loss): 0.235
# dice score (1-dice_loss): 0.171
# dicetotal:2.389
# iteration 170 : loss : 1.496187, loss_seg : 0.603487, loss_seg_dice : 2.388888
#
#
# dice score (1-dice_loss): 0.954
# dice score (1-dice_loss): 0.304
# dice score (1-dice_loss): 0.201
# dice score (1-dice_loss): 0.121
# dicetotal:2.420
# iteration 171 : loss : 1.700782, loss_seg : 0.981523, loss_seg_dice : 2.420041
#
#
# dice score (1-dice_loss): 0.958
# dice score (1-dice_loss): 0.281
# dice score (1-dice_loss): 0.241
# dice score (1-dice_loss): 0.169
# dicetotal:2.352
# iteration 172 : loss : 1.490770, loss_seg : 0.629401, loss_seg_dice : 2.352138
#   3%|▊                            | 43/1501 [13:17<7:36:45, 18.80s/it]
# dice score (1-dice_loss): 0.958
# dice score (1-dice_loss): 0.282
# dice score (1-dice_loss): 0.250
# dice score (1-dice_loss): 0.143
# dicetotal:2.367
# iteration 173 : loss : 1.457426, loss_seg : 0.548325, loss_seg_dice : 2.366528
#
#
# dice score (1-dice_loss): 0.961
# dice score (1-dice_loss): 0.200
# dice score (1-dice_loss): 0.228
# dice score (1-dice_loss): 0.163
# dicetotal:2.448
# iteration 174 : loss : 1.462702, loss_seg : 0.477616, loss_seg_dice : 2.447787
#
#
# dice score (1-dice_loss): 0.962
# dice score (1-dice_loss): 0.277
# dice score (1-dice_loss): 0.243
# dice score (1-dice_loss): 0.148
# dicetotal:2.371
# iteration 175 : loss : 1.499772, loss_seg : 0.629023, loss_seg_dice : 2.370521
#
#
# dice score (1-dice_loss): 0.950
# dice score (1-dice_loss): 0.214
# dice score (1-dice_loss): 0.213
# dice score (1-dice_loss): 0.167
# dicetotal:2.456
# iteration 176 : loss : 1.660384, loss_seg : 0.865257, loss_seg_dice : 2.455511
#   3%|▊                            | 44/1501 [13:34<7:29:56, 18.53s/it]
# dice score (1-dice_loss): 0.968
# dice score (1-dice_loss): 0.210
# dice score (1-dice_loss): 0.259
# dice score (1-dice_loss): 0.156
# dicetotal:2.407
# iteration 177 : loss : 1.432462, loss_seg : 0.457452, loss_seg_dice : 2.407472
#
#
# dice score (1-dice_loss): 0.966
# dice score (1-dice_loss): 0.275
# dice score (1-dice_loss): 0.293
# dice score (1-dice_loss): 0.175
# dicetotal:2.290
# iteration 178 : loss : 1.419084, loss_seg : 0.547893, loss_seg_dice : 2.290275
#
#
# dice score (1-dice_loss): 0.962
# dice score (1-dice_loss): 0.267
# dice score (1-dice_loss): 0.232
# dice score (1-dice_loss): 0.134
# dicetotal:2.405
# iteration 179 : loss : 1.486634, loss_seg : 0.567842, loss_seg_dice : 2.405427
#
#
# dice score (1-dice_loss): 0.960
# dice score (1-dice_loss): 0.215
# dice score (1-dice_loss): 0.271
# dice score (1-dice_loss): 0.123
# dicetotal:2.431
# iteration 180 : loss : 1.506276, loss_seg : 0.581899, loss_seg_dice : 2.430653
#   3%|▊                            | 45/1501 [13:53<7:28:48, 18.49s/it]
# dice score (1-dice_loss): 0.964
# dice score (1-dice_loss): 0.266
# dice score (1-dice_loss): 0.282
# dice score (1-dice_loss): 0.176
# dicetotal:2.313
# iteration 181 : loss : 1.474330, loss_seg : 0.635758, loss_seg_dice : 2.312901
#
#
# dice score (1-dice_loss): 0.961
# dice score (1-dice_loss): 0.299
# dice score (1-dice_loss): 0.242
# dice score (1-dice_loss): 0.176
# dicetotal:2.321
# iteration 182 : loss : 1.453354, loss_seg : 0.585591, loss_seg_dice : 2.321116
#
#
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.290
# dice score (1-dice_loss): 0.216
# dice score (1-dice_loss): 0.176
# dicetotal:2.362
# iteration 183 : loss : 1.500667, loss_seg : 0.639031, loss_seg_dice : 2.362304
#
#
# dice score (1-dice_loss): 0.956
# dice score (1-dice_loss): 0.310
# dice score (1-dice_loss): 0.227
# dice score (1-dice_loss): 0.149
# dicetotal:2.357
# iteration 184 : loss : 1.480280, loss_seg : 0.603119, loss_seg_dice : 2.357440
#   3%|▉                            | 46/1501 [14:11<7:24:22, 18.32s/it]
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.275
# dice score (1-dice_loss): 0.239
# dice score (1-dice_loss): 0.169
# dicetotal:2.361
# iteration 185 : loss : 1.504341, loss_seg : 0.647637, loss_seg_dice : 2.361046
#
#
# dice score (1-dice_loss): 0.956
# dice score (1-dice_loss): 0.292
# dice score (1-dice_loss): 0.241
# dice score (1-dice_loss): 0.139
# dicetotal:2.373
# iteration 186 : loss : 1.551322, loss_seg : 0.730020, loss_seg_dice : 2.372623
#
#
# dice score (1-dice_loss): 0.956
# dice score (1-dice_loss): 0.247
# dice score (1-dice_loss): 0.237
# dice score (1-dice_loss): 0.157
# dicetotal:2.403
# iteration 187 : loss : 1.497700, loss_seg : 0.592600, loss_seg_dice : 2.402802
#
#
# dice score (1-dice_loss): 0.959
# dice score (1-dice_loss): 0.308
# dice score (1-dice_loss): 0.230
# dice score (1-dice_loss): 0.158
# dicetotal:2.346
# iteration 188 : loss : 1.492617, loss_seg : 0.639508, loss_seg_dice : 2.345727
#   3%|▉                            | 47/1501 [14:29<7:20:24, 18.17s/it]
# dice score (1-dice_loss): 0.960
# dice score (1-dice_loss): 0.322
# dice score (1-dice_loss): 0.249
# dice score (1-dice_loss): 0.199
# dicetotal:2.270
# iteration 189 : loss : 1.460637, loss_seg : 0.651562, loss_seg_dice : 2.269712
#
#
# dice score (1-dice_loss): 0.957
# dice score (1-dice_loss): 0.319
# dice score (1-dice_loss): 0.263
# dice score (1-dice_loss): 0.111
# dicetotal:2.350
# iteration 190 : loss : 1.506891, loss_seg : 0.664107, loss_seg_dice : 2.349675
#
#
# dice score (1-dice_loss): 0.961
# dice score (1-dice_loss): 0.292
# dice score (1-dice_loss): 0.232
# dice score (1-dice_loss): 0.134
# dicetotal:2.381
# iteration 191 : loss : 1.420835, loss_seg : 0.460533, loss_seg_dice : 2.381137
#
#
# dice score (1-dice_loss): 0.949
# dice score (1-dice_loss): 0.191
# dice score (1-dice_loss): 0.215
# dice score (1-dice_loss): 0.148
# dicetotal:2.496
# iteration 192 : loss : 1.514445, loss_seg : 0.532421, loss_seg_dice : 2.496469
#   3%|▉                            | 48/1501 [14:46<7:13:54, 17.92s/it]
# dice score (1-dice_loss): 0.959
# dice score (1-dice_loss): 0.278
# dice score (1-dice_loss): 0.224
# dice score (1-dice_loss): 0.135
# dicetotal:2.403
# iteration 193 : loss : 1.506150, loss_seg : 0.609231, loss_seg_dice : 2.403069
#
#
# dice score (1-dice_loss): 0.960
# dice score (1-dice_loss): 0.297
# dice score (1-dice_loss): 0.240
# dice score (1-dice_loss): 0.156
# dicetotal:2.347
# iteration 194 : loss : 1.478637, loss_seg : 0.610261, loss_seg_dice : 2.347013
#
#
# dice score (1-dice_loss): 0.956
# dice score (1-dice_loss): 0.327
# dice score (1-dice_loss): 0.237
# dice score (1-dice_loss): 0.188
# dicetotal:2.292
# iteration 195 : loss : 1.493555, loss_seg : 0.695180, loss_seg_dice : 2.291929
#
#
# dice score (1-dice_loss): 0.960
# dice score (1-dice_loss): 0.344
# dice score (1-dice_loss): 0.218
# dice score (1-dice_loss): 0.172
# dicetotal:2.306
# iteration 196 : loss : 1.466000, loss_seg : 0.626304, loss_seg_dice : 2.305696
#   3%|▉                            | 49/1501 [15:05<7:23:52, 18.34s/it]
# dice score (1-dice_loss): 0.953
# dice score (1-dice_loss): 0.295
# dice score (1-dice_loss): 0.261
# dice score (1-dice_loss): 0.176
# dicetotal:2.314
# iteration 197 : loss : 1.491086, loss_seg : 0.667856, loss_seg_dice : 2.314317
#
#
# dice score (1-dice_loss): 0.954
# dice score (1-dice_loss): 0.279
# dice score (1-dice_loss): 0.204
# ...
#  99%|██████████████████████████▋| 1484/1501 [7:33:41<05:16, 18.64s/it]
# dice score (1-dice_loss): 0.992
# dice score (1-dice_loss): 0.781
# dice score (1-dice_loss): 0.689
# dice score (1-dice_loss): 0.747
# dicetotal:0.791
# iteration 5937 : loss : 0.463701, loss_seg : 0.136370, loss_seg_dice : 0.791032
#
#
# dice score (1-dice_loss): 0.993
# dice score (1-dice_loss): 0.842
# dice score (1-dice_loss): 0.733
# dice score (1-dice_loss): 0.677
# dicetotal:0.755
# iteration 5938 : loss : 0.433684, loss_seg : 0.112184, loss_seg_dice : 0.755184
#
#
# dice score (1-dice_loss): 0.991
# dice score (1-dice_loss): 0.829
# dice score (1-dice_loss): 0.798
# dice score (1-dice_loss): 0.670
# dicetotal:0.712
# iteration 5939 : loss : 0.449433, loss_seg : 0.186451, loss_seg_dice : 0.712416
#
#
# dice score (1-dice_loss): 0.990
# dice score (1-dice_loss): 0.857
# dice score (1-dice_loss): 0.768
# dice score (1-dice_loss): 0.683
# dicetotal:0.702
# iteration 5940 : loss : 0.452761, loss_seg : 0.203765, loss_seg_dice : 0.701757
#  99%|██████████████████████████▋| 1485/1501 [7:34:00<04:57, 18.62s/it]
# dice score (1-dice_loss): 0.993
# dice score (1-dice_loss): 0.859
# dice score (1-dice_loss): 0.732
# dice score (1-dice_loss): 0.562
# dicetotal:0.854
# iteration 5941 : loss : 0.495991, loss_seg : 0.138434, loss_seg_dice : 0.853547
#
#
# dice score (1-dice_loss): 0.991
# dice score (1-dice_loss): 0.859
# dice score (1-dice_loss): 0.726
# dice score (1-dice_loss): 0.700
# dicetotal:0.724
# iteration 5942 : loss : 0.447190, loss_seg : 0.170109, loss_seg_dice : 0.724271
#
#
# dice score (1-dice_loss): 0.992
# dice score (1-dice_loss): 0.713
# dice score (1-dice_loss): 0.646
# dice score (1-dice_loss): 0.543
# dicetotal:1.107
# iteration 5943 : loss : 0.701725, loss_seg : 0.296896, loss_seg_dice : 1.106555
#
#
# dice score (1-dice_loss): 0.992
# dice score (1-dice_loss): 0.837
# dice score (1-dice_loss): 0.796
# dice score (1-dice_loss): 0.625
# dicetotal:0.751
# iteration 5944 : loss : 0.475864, loss_seg : 0.200699, loss_seg_dice : 0.751029
#  99%|██████████████████████████▋| 1486/1501 [7:34:18<04:35, 18.36s/it]
# dice score (1-dice_loss): 0.992
# dice score (1-dice_loss): 0.817
# dice score (1-dice_loss): 0.762
# dice score (1-dice_loss): 0.748
# dicetotal:0.682
# iteration 5945 : loss : 0.433348, loss_seg : 0.185033, loss_seg_dice : 0.681663
#
#
# dice score (1-dice_loss): 0.991
# dice score (1-dice_loss): 0.852
# dice score (1-dice_loss): 0.752
# dice score (1-dice_loss): 0.682
# dicetotal:0.723
# iteration 5946 : loss : 0.457293, loss_seg : 0.192036, loss_seg_dice : 0.722549
#
#
# dice score (1-dice_loss): 0.971
# dice score (1-dice_loss): 0.503
# dice score (1-dice_loss): 0.635
# dice score (1-dice_loss): 0.509
# dicetotal:1.381
# iteration 5947 : loss : 0.897520, loss_seg : 0.413916, loss_seg_dice : 1.381124
#
#
# dice score (1-dice_loss): 0.992
# dice score (1-dice_loss): 0.817
# dice score (1-dice_loss): 0.738
# dice score (1-dice_loss): 0.694
# dicetotal:0.759
# iteration 5948 : loss : 0.483698, loss_seg : 0.208313, loss_seg_dice : 0.759083
#  99%|██████████████████████████▋| 1487/1501 [7:34:35<04:14, 18.19s/it]
# dice score (1-dice_loss): 0.989
# dice score (1-dice_loss): 0.838
# dice score (1-dice_loss): 0.765
# dice score (1-dice_loss): 0.648
# dicetotal:0.759
# iteration 5949 : loss : 0.480976, loss_seg : 0.203421, loss_seg_dice : 0.758531
#
#
# dice score (1-dice_loss): 0.991
# dice score (1-dice_loss): 0.872
# dice score (1-dice_loss): 0.781
# dice score (1-dice_loss): 0.667
# dicetotal:0.689
# iteration 5950 : loss : 0.455584, loss_seg : 0.222134, loss_seg_dice : 0.689034
#
#
# dice score (1-dice_loss): 0.992
# dice score (1-dice_loss): 0.807
# dice score (1-dice_loss): 0.729
# dice score (1-dice_loss): 0.744
# dicetotal:0.728
# iteration 5951 : loss : 0.417645, loss_seg : 0.107164, loss_seg_dice : 0.728126
#
#
# dice score (1-dice_loss): 0.993
# dice score (1-dice_loss): 0.852
# dice score (1-dice_loss): 0.688
# dice score (1-dice_loss): 0.723
# dicetotal:0.745
# iteration 5952 : loss : 0.464755, loss_seg : 0.184327, loss_seg_dice : 0.745183
#  99%|██████████████████████████▊| 1488/1501 [7:34:55<04:02, 18.64s/it]
# dice score (1-dice_loss): 0.989
# dice score (1-dice_loss): 0.801
# dice score (1-dice_loss): 0.673
# dice score (1-dice_loss): 0.431
# dicetotal:1.106
# iteration 5953 : loss : 0.748019, loss_seg : 0.390424, loss_seg_dice : 1.105614
#
#
# dice score (1-dice_loss): 0.993
# dice score (1-dice_loss): 0.869
# dice score (1-dice_loss): 0.714
# dice score (1-dice_loss): 0.715
# dicetotal:0.708
# iteration 5954 : loss : 0.417175, loss_seg : 0.126429, loss_seg_dice : 0.707921
#
#
# dice score (1-dice_loss): 0.991
# dice score (1-dice_loss): 0.825
# dice score (1-dice_loss): 0.706
# dice score (1-dice_loss): 0.536
# dicetotal:0.941
# iteration 5955 : loss : 0.578592, loss_seg : 0.215736, loss_seg_dice : 0.941447
#
#
# dice score (1-dice_loss): 0.992
# dice score (1-dice_loss): 0.796
# dice score (1-dice_loss): 0.719
# dice score (1-dice_loss): 0.600
# dicetotal:0.894
# iteration 5956 : loss : 0.526133, loss_seg : 0.158525, loss_seg_dice : 0.893740
#  99%|██████████████████████████▊| 1489/1501 [7:35:13<03:41, 18.45s/it]
# dice score (1-dice_loss): 0.989
# dice score (1-dice_loss): 0.753
# dice score (1-dice_loss): 0.628
# dice score (1-dice_loss): 0.658
# dicetotal:0.971
# iteration 5957 : loss : 0.594382, loss_seg : 0.217296, loss_seg_dice : 0.971468
#
#
# dice score (1-dice_loss): 0.991
# dice score (1-dice_loss): 0.779
# dice score (1-dice_loss): 0.662
# dice score (1-dice_loss): 0.629
# dicetotal:0.939
# iteration 5958 : loss : 0.590659, loss_seg : 0.242676, loss_seg_dice : 0.938641
#
#
# dice score (1-dice_loss): 0.990
# dice score (1-dice_loss): 0.832
# dice score (1-dice_loss): 0.755
# dice score (1-dice_loss): 0.680
# dicetotal:0.743
# iteration 5959 : loss : 0.442001, loss_seg : 0.140798, loss_seg_dice : 0.743205
#
#
# dice score (1-dice_loss): 0.989
# dice score (1-dice_loss): 0.830
# dice score (1-dice_loss): 0.732
# dice score (1-dice_loss): 0.746
# dicetotal:0.703
# iteration 5960 : loss : 0.432177, loss_seg : 0.161694, loss_seg_dice : 0.702660
#  99%|██████████████████████████▊| 1490/1501 [7:35:32<03:23, 18.49s/it]
# dice score (1-dice_loss): 0.992
# dice score (1-dice_loss): 0.817
# dice score (1-dice_loss): 0.754
# dice score (1-dice_loss): 0.639
# dicetotal:0.798
# iteration 5961 : loss : 0.506899, loss_seg : 0.215944, loss_seg_dice : 0.797854
#
#
# dice score (1-dice_loss): 0.991
# dice score (1-dice_loss): 0.847
# dice score (1-dice_loss): 0.650
# dice score (1-dice_loss): 0.688
# dicetotal:0.824
# iteration 5962 : loss : 0.498650, loss_seg : 0.173266, loss_seg_dice : 0.824035
#
#
# dice score (1-dice_loss): 0.990
# dice score (1-dice_loss): 0.865
# dice score (1-dice_loss): 0.765
# dice score (1-dice_loss): 0.683
# dicetotal:0.697
# iteration 5963 : loss : 0.446062, loss_seg : 0.195617, loss_seg_dice : 0.696508
#
#
# dice score (1-dice_loss): 0.992
# dice score (1-dice_loss): 0.855
# dice score (1-dice_loss): 0.755
# dice score (1-dice_loss): 0.710
# dicetotal:0.687
# iteration 5964 : loss : 0.429481, loss_seg : 0.171965, loss_seg_dice : 0.686997
#  99%|██████████████████████████▊| 1491/1501 [7:35:50<03:03, 18.38s/it]
# dice score (1-dice_loss): 0.991
# dice score (1-dice_loss): 0.854
# dice score (1-dice_loss): 0.705
# dice score (1-dice_loss): 0.727
# dicetotal:0.724
# iteration 5965 : loss : 0.443450, loss_seg : 0.163114, loss_seg_dice : 0.723786
#
#
# dice score (1-dice_loss): 0.987
# dice score (1-dice_loss): 0.813
# dice score (1-dice_loss): 0.756
# dice score (1-dice_loss): 0.707
# dicetotal:0.737
# iteration 5966 : loss : 0.475264, loss_seg : 0.213218, loss_seg_dice : 0.737310
#
#
# dice score (1-dice_loss): 0.992
# dice score (1-dice_loss): 0.855
# dice score (1-dice_loss): 0.784
# dice score (1-dice_loss): 0.688
# dicetotal:0.681
# iteration 5967 : loss : 0.419105, loss_seg : 0.156791, loss_seg_dice : 0.681418
#
#
# dice score (1-dice_loss): 0.994
# dice score (1-dice_loss): 0.866
# dice score (1-dice_loss): 0.805
# dice score (1-dice_loss): 0.726
# dicetotal:0.609
# iteration 5968 : loss : 0.375061, loss_seg : 0.140731, loss_seg_dice : 0.609390
#  99%|██████████████████████████▊| 1492/1501 [7:36:07<02:41, 17.97s/it]
# dice score (1-dice_loss): 0.991
# dice score (1-dice_loss): 0.843
# dice score (1-dice_loss): 0.767
# dice score (1-dice_loss): 0.626
# dicetotal:0.772
# iteration 5969 : loss : 0.489143, loss_seg : 0.205907, loss_seg_dice : 0.772379
#
#
# dice score (1-dice_loss): 0.991
# dice score (1-dice_loss): 0.776
# dice score (1-dice_loss): 0.679
# dice score (1-dice_loss): 0.536
# dicetotal:1.018
# iteration 5970 : loss : 0.623596, loss_seg : 0.228792, loss_seg_dice : 1.018399
#
#
# dice score (1-dice_loss): 0.992
# dice score (1-dice_loss): 0.818
# dice score (1-dice_loss): 0.789
# dice score (1-dice_loss): 0.747
# dicetotal:0.654
# iteration 5971 : loss : 0.420380, loss_seg : 0.186584, loss_seg_dice : 0.654176
#
#
# dice score (1-dice_loss): 0.989
# dice score (1-dice_loss): 0.831
# dice score (1-dice_loss): 0.752
# dice score (1-dice_loss): 0.619
# dicetotal:0.809
# iteration 5972 : loss : 0.530836, loss_seg : 0.253070, loss_seg_dice : 0.808602
#  99%|██████████████████████████▊| 1493/1501 [7:36:25<02:24, 18.12s/it]
# dice score (1-dice_loss): 0.990
# dice score (1-dice_loss): 0.832
# dice score (1-dice_loss): 0.810
# dice score (1-dice_loss): 0.724
# dicetotal:0.644
# iteration 5973 : loss : 0.420285, loss_seg : 0.196833, loss_seg_dice : 0.643736
#
#
# dice score (1-dice_loss): 0.989
# dice score (1-dice_loss): 0.837
# dice score (1-dice_loss): 0.763
# dice score (1-dice_loss): 0.615
# dicetotal:0.796
# iteration 5974 : loss : 0.496205, loss_seg : 0.196444, loss_seg_dice : 0.795965
#
#
# dice score (1-dice_loss): 0.992
# dice score (1-dice_loss): 0.848
# dice score (1-dice_loss): 0.718
# dice score (1-dice_loss): 0.738
# dicetotal:0.703
# iteration 5975 : loss : 0.426482, loss_seg : 0.150349, loss_seg_dice : 0.702615
#
#
# dice score (1-dice_loss): 0.992
# dice score (1-dice_loss): 0.873
# dice score (1-dice_loss): 0.799
# dice score (1-dice_loss): 0.752
# dicetotal:0.585
# iteration 5976 : loss : 0.368933, loss_seg : 0.152984, loss_seg_dice : 0.584882
# 100%|██████████████████████████▊| 1494/1501 [7:36:45<02:09, 18.49s/it]
# dice score (1-dice_loss): 0.991
# dice score (1-dice_loss): 0.859
# dice score (1-dice_loss): 0.785
# dice score (1-dice_loss): 0.661
# dicetotal:0.704
# iteration 5977 : loss : 0.450436, loss_seg : 0.196837, loss_seg_dice : 0.704034
#
#
# dice score (1-dice_loss): 0.992
# dice score (1-dice_loss): 0.783
# dice score (1-dice_loss): 0.821
# dice score (1-dice_loss): 0.748
# dicetotal:0.657
# iteration 5978 : loss : 0.416515, loss_seg : 0.176066, loss_seg_dice : 0.656964
#
#
# dice score (1-dice_loss): 0.991
# dice score (1-dice_loss): 0.872
# dice score (1-dice_loss): 0.775
# dice score (1-dice_loss): 0.725
# dicetotal:0.638
# iteration 5979 : loss : 0.416545, loss_seg : 0.194758, loss_seg_dice : 0.638333
#
#
# dice score (1-dice_loss): 0.990
# dice score (1-dice_loss): 0.795
# dice score (1-dice_loss): 0.730
# dice score (1-dice_loss): 0.764
# dicetotal:0.721
# iteration 5980 : loss : 0.474234, loss_seg : 0.227429, loss_seg_dice : 0.721040
# 100%|██████████████████████████▉| 1495/1501 [7:37:03<01:50, 18.37s/it]
# dice score (1-dice_loss): 0.991
# dice score (1-dice_loss): 0.851
# dice score (1-dice_loss): 0.716
# dice score (1-dice_loss): 0.670
# dicetotal:0.771
# iteration 5981 : loss : 0.486415, loss_seg : 0.202250, loss_seg_dice : 0.770580
#
#
# dice score (1-dice_loss): 0.991
# dice score (1-dice_loss): 0.765
# dice score (1-dice_loss): 0.721
# dice score (1-dice_loss): 0.596
# dicetotal:0.927
# iteration 5982 : loss : 0.576177, loss_seg : 0.225249, loss_seg_dice : 0.927105
#
#
# dice score (1-dice_loss): 0.993
# dice score (1-dice_loss): 0.766
# dice score (1-dice_loss): 0.661
# dice score (1-dice_loss): 0.624
# dicetotal:0.956
# iteration 5983 : loss : 0.592830, loss_seg : 0.229742, loss_seg_dice : 0.955917
#
#
# dice score (1-dice_loss): 0.988
# dice score (1-dice_loss): 0.832
# dice score (1-dice_loss): 0.669
# dice score (1-dice_loss): 0.563
# dicetotal:0.948
# iteration 5984 : loss : 0.593811, loss_seg : 0.239945, loss_seg_dice : 0.947676
# 100%|██████████████████████████▉| 1496/1501 [7:37:21<01:32, 18.48s/it]
# dice score (1-dice_loss): 0.992
# dice score (1-dice_loss): 0.860
# dice score (1-dice_loss): 0.751
# dice score (1-dice_loss): 0.590
# dicetotal:0.807
# iteration 5985 : loss : 0.494425, loss_seg : 0.181544, loss_seg_dice : 0.807307
#
#
# dice score (1-dice_loss): 0.989
# dice score (1-dice_loss): 0.846
# dice score (1-dice_loss): 0.743
# dice score (1-dice_loss): 0.649
# dicetotal:0.772
# iteration 5986 : loss : 0.482253, loss_seg : 0.192581, loss_seg_dice : 0.771926
#
#
# dice score (1-dice_loss): 0.992
# dice score (1-dice_loss): 0.752
# dice score (1-dice_loss): 0.757
# dice score (1-dice_loss): 0.663
# dicetotal:0.836
# iteration 5987 : loss : 0.522421, loss_seg : 0.209120, loss_seg_dice : 0.835723
#
#
# dice score (1-dice_loss): 0.993
# dice score (1-dice_loss): 0.870
# dice score (1-dice_loss): 0.716
# dice score (1-dice_loss): 0.645
# dicetotal:0.776
# iteration 5988 : loss : 0.462096, loss_seg : 0.148173, loss_seg_dice : 0.776020
# 100%|██████████████████████████▉| 1497/1501 [7:37:39<01:12, 18.20s/it]
# dice score (1-dice_loss): 0.992
# dice score (1-dice_loss): 0.822
# dice score (1-dice_loss): 0.733
# dice score (1-dice_loss): 0.696
# dicetotal:0.757
# iteration 5989 : loss : 0.455748, loss_seg : 0.154132, loss_seg_dice : 0.757364
#
#
# dice score (1-dice_loss): 0.991
# dice score (1-dice_loss): 0.808
# dice score (1-dice_loss): 0.761
# dice score (1-dice_loss): 0.717
# dicetotal:0.723
# iteration 5990 : loss : 0.467788, loss_seg : 0.213006, loss_seg_dice : 0.722570
#
#
# dice score (1-dice_loss): 0.992
# dice score (1-dice_loss): 0.809
# dice score (1-dice_loss): 0.785
# dice score (1-dice_loss): 0.606
# dicetotal:0.808
# iteration 5991 : loss : 0.491418, loss_seg : 0.174937, loss_seg_dice : 0.807899
#
#
# dice score (1-dice_loss): 0.990
# dice score (1-dice_loss): 0.819
# dice score (1-dice_loss): 0.733
# dice score (1-dice_loss): 0.738
# dicetotal:0.720
# iteration 5992 : loss : 0.454655, loss_seg : 0.189511, loss_seg_dice : 0.719798
# 100%|██████████████████████████▉| 1498/1501 [7:37:58<00:55, 18.55s/it]
# dice score (1-dice_loss): 0.992
# dice score (1-dice_loss): 0.851
# dice score (1-dice_loss): 0.792
# dice score (1-dice_loss): 0.744
# dicetotal:0.620
# iteration 5993 : loss : 0.389904, loss_seg : 0.159777, loss_seg_dice : 0.620031
#
#
# dice score (1-dice_loss): 0.990
# dice score (1-dice_loss): 0.850
# dice score (1-dice_loss): 0.763
# dice score (1-dice_loss): 0.732
# dicetotal:0.665
# iteration 5994 : loss : 0.406082, loss_seg : 0.146691, loss_seg_dice : 0.665472
#
#
# dice score (1-dice_loss): 0.990
# dice score (1-dice_loss): 0.844
# dice score (1-dice_loss): 0.814
# dice score (1-dice_loss): 0.753
# dicetotal:0.598
# iteration 5995 : loss : 0.389046, loss_seg : 0.179804, loss_seg_dice : 0.598289
#
#
# dice score (1-dice_loss): 0.991
# dice score (1-dice_loss): 0.846
# dice score (1-dice_loss): 0.764
# dice score (1-dice_loss): 0.712
# dicetotal:0.686
# iteration 5996 : loss : 0.438774, loss_seg : 0.191716, loss_seg_dice : 0.685833
# 100%|██████████████████████████▉| 1499/1501 [7:38:18<00:37, 18.78s/it]
# dice score (1-dice_loss): 0.991
# dice score (1-dice_loss): 0.870
# dice score (1-dice_loss): 0.780
# dice score (1-dice_loss): 0.644
# dicetotal:0.715
# iteration 5997 : loss : 0.446414, loss_seg : 0.177924, loss_seg_dice : 0.714904
#
#
# dice score (1-dice_loss): 0.989
# dice score (1-dice_loss): 0.829
# dice score (1-dice_loss): 0.778
# dice score (1-dice_loss): 0.723
# dicetotal:0.681
# iteration 5998 : loss : 0.437843, loss_seg : 0.194648, loss_seg_dice : 0.681038
#
#
# dice score (1-dice_loss): 0.991
# dice score (1-dice_loss): 0.835
# dice score (1-dice_loss): 0.766
# dice score (1-dice_loss): 0.708
# dicetotal:0.700
# iteration 5999 : loss : 0.441948, loss_seg : 0.183858, loss_seg_dice : 0.700039
#
#
# dice score (1-dice_loss): 0.991
# dice score (1-dice_loss): 0.855
# dice score (1-dice_loss): 0.762
# dice score (1-dice_loss): 0.633
# dicetotal:0.758
# iteration 6000 : loss : 0.509368, loss_seg : 0.260416, loss_seg_dice : 0.758319
# save model to ../model/vnet_supervisedonly_dp/iter_6000.pth
# 100%|██████████████████████████▉| 1500/1501 [7:38:36<00:18, 18.53s/it]
# dice score (1-dice_loss): 0.986
# dice score (1-dice_loss): 0.806
# dice score (1-dice_loss): 0.760
# dice score (1-dice_loss): 0.736
# dicetotal:0.711
# iteration 6001 : loss : 0.543259, loss_seg : 0.375092, loss_seg_dice : 0.711426
# save model to ../model/vnet_supervisedonly_dp/iter_6001.pth
