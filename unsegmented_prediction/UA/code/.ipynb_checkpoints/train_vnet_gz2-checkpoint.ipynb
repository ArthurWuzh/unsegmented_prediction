# %%
import os
import sys
from tqdm import tqdm
from tensorboardX import SummaryWriter
import shutil
import argparse
import logging
import time
import random
import numpy as np

import torch
import torch.optim as optim
from torchvision import transforms
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
from torch.utils.data import DataLoader
from torchvision.utils import make_grid

from networks.vnet import VNet
# from utils.losses import dice_loss
from utils import ramps, losses
from dataloaders.la_heart_sitk import LAHeart, RandomScale, RandomNoise, RandomCrop, CenterCrop, RandomRot, RandomFlip, ToTensor, TwoStreamBatchSampler
# -

# %%
parser = argparse.ArgumentParser()
parser.add_argument('--root_path', type=str, default='../../data/gz_dataset/segmented', help='Name of Experiment')
parser.add_argument('--exp', type=str,  default='vnet_supervisedonly_dp', help='model_name')
parser.add_argument('--max_iterations', type=int,  default=6000, help='maximum epoch number to train')
parser.add_argument('--batch_size', type=int, default=8, help='batch_size per gpu')
parser.add_argument('--base_lr', type=float,  default=0.01, help='maximum epoch number to train')
parser.add_argument('--deterministic', type=int,  default=1, help='whether use deterministic training')
parser.add_argument('--seed', type=int,  default=1337, help='random seed')
parser.add_argument('--gpu', type=str,  default='0', help='GPU to use')
args = parser.parse_args(args=[])

train_data_path = args.root_path
snapshot_path = "../model/" + args.exp + "/"

os.environ['CUDA_VISIBLE_DEVICES'] = args.gpu
batch_size = args.batch_size * len(args.gpu.split(','))
max_iterations = args.max_iterations
base_lr = args.base_lr

# %%
if args.deterministic:
    cudnn.benchmark = False
    cudnn.deterministic = True
    random.seed(args.seed)
    np.random.seed(args.seed)
    torch.manual_seed(args.seed)
    torch.cuda.manual_seed(args.seed)

num_classes = 4
patch_size = (128, 128, 64)
cls_weights = [1,5,5,15]

# %%
if not os.path.exists(snapshot_path):
    os.makedirs(snapshot_path)
if os.path.exists(snapshot_path + '/code'):
    shutil.rmtree(snapshot_path + '/code')
shutil.copytree('.', snapshot_path + '/code', shutil.ignore_patterns(['.git','__pycache__']))

logging.basicConfig(filename=snapshot_path+"/log.txt", level=logging.INFO,
                    format='[%(asctime)s.%(msecs)03d] %(message)s', datefmt='%H:%M:%S')
logging.getLogger().addHandler(logging.StreamHandler(sys.stdout))
logging.info(str(args))

net = VNet(n_channels=1, n_classes=num_classes, normalization='batchnorm', has_dropout=True)
net = net.cuda()

db_train = LAHeart(base_dir=train_data_path,
                    split='train',
                    #num=16,
                    transform = transforms.Compose([
#                       RandomScale(ratio_low=0.6, ratio_high=1.5),
                        RandomNoise(mu=0, sigma=0.05),
                        RandomRot(),
                        RandomFlip(),
                        RandomCrop(patch_size),
                        ToTensor(),
                        ]))
db_test = LAHeart(base_dir=train_data_path,
                    split='test',
                    transform = transforms.Compose([
                        CenterCrop(patch_size),
                        ToTensor()
                    ]))
def worker_init_fn(worker_id):
    random.seed(args.seed+worker_id)
trainloader = DataLoader(
    db_train, 
    batch_size=batch_size, 
    shuffle=True,  
    num_workers=6,#4, 
    pin_memory=True, 
    worker_init_fn=worker_init_fn
)

net.train()
optimizer = optim.SGD(net.parameters(), lr=base_lr, momentum=0.9, weight_decay=0.0001)

writer = SummaryWriter(snapshot_path+'/log')
logging.info("{} itertations per epoch".format(len(trainloader)))

iter_num = 0
max_epoch = max_iterations//len(trainloader)+1
lr_ = base_lr
net.train()
for epoch_num in tqdm(range(max_epoch), ncols=70):
    time1 = time.time()
    for i_batch, sampled_batch in enumerate(trainloader):
#           import pdb
#           pdb.set_trace()
        time2 = time.time()
        # print('fetch data cost {}'.format(time2-time1))
        volume_batch, label_batch = sampled_batch['image'], sampled_batch['label']
        volume_batch, label_batch = volume_batch.cuda(), label_batch.cuda()
        outputs = net(volume_batch)
        
        loss_seg = F.cross_entropy( outputs, label_batch, weight=torch.tensor(cls_weights,dtype=torch.float32).cuda() )
        outputs_soft = F.softmax(outputs, dim=1)
        loss_seg_dice = 0
        print('\n')
        for i in range(num_classes):
            loss_mid = losses.dice_loss(outputs_soft[:, i, :, :, :], label_batch == i )
            loss_seg_dice += loss_mid
            print('dice score (1-dice_loss): {:.3f}'.format(1-loss_mid))
        print('dicetotal:{:.3f}'.format( loss_seg_dice))
        loss = 0.5*(loss_seg+loss_seg_dice)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        iter_num = iter_num + 1
        writer.add_scalar('lr', lr_, iter_num)
        writer.add_scalar('loss/loss_seg', loss_seg, iter_num)
        writer.add_scalar('loss/loss_seg_dice', loss_seg_dice, iter_num)
        writer.add_scalar('loss/loss', loss, iter_num)
        logging.info('iteration %d : loss : %f, loss_seg : %f, loss_seg_dice : %f' % 
                        (iter_num, 
                        loss.item(),
                        loss_seg.item(),
                        loss_seg_dice.item())
                    )
        if iter_num % 50 == 0:
            image = volume_batch[0, 0:1, :, :, 20:61:10].permute(3,0,1,2).repeat(1,3,1,1)
            grid_image = make_grid(image, 5, normalize=True)
            writer.add_image('train/Image', grid_image, iter_num)

            outputs_soft = F.softmax(outputs, 1)
            image = outputs_soft[0, 1:2, :, :, 20:61:10].permute(3, 0, 1, 2).repeat(1, 3, 1, 1)
            grid_image = make_grid(image, 5, normalize=False)
            writer.add_image('train/Predicted_label', grid_image, iter_num)

            image = label_batch[0, :, :, 20:61:10].unsqueeze(0).permute(3, 0, 1, 2).repeat(1, 3, 1, 1)
            grid_image = make_grid(image, 5, normalize=False)
            writer.add_image('train/Groundtruth_label', grid_image, iter_num)

        ## change lr
        if iter_num % 2500 == 0:
            lr_ = base_lr * 0.1 ** (iter_num // 2500)
            for param_group in optimizer.param_groups:
                param_group['lr'] = lr_
        if iter_num % 500 == 0:
            save_mode_path = os.path.join(snapshot_path, 'iter_' + str(iter_num) + '.pth')
            torch.save(net.state_dict(), save_mode_path)
            logging.info("save model to {}".format(save_mode_path))

        if iter_num > max_iterations:
            break
        time1 = time.time()
    if iter_num > max_iterations:
        break
save_mode_path = os.path.join(snapshot_path, 'iter_'+str(max_iterations+1)+'.pth')
torch.save(net.state_dict(), save_mode_path)
logging.info("save model to {}".format(save_mode_path))
writer.close()
# Out:
# Namespace(base_lr=0.01, batch_size=8, deterministic=1, exp='vnet_supervisedonly_dp', gpu='0', max_iterations=6000, root_path='../../data/gz_dataset/segmented', seed=1337)
# total 32 samples
# total 8 samples
# 4 itertations per epoch
#   0%|                                        | 0/1501 [00:00<?, ?it/s]
# dice score (1-dice_loss): 0.546
# dice score (1-dice_loss): 0.168
# dice score (1-dice_loss): 0.166
# dice score (1-dice_loss): 0.073
# dicetotal:3.048
# iteration 1 : loss : 2.211803, loss_seg : 1.375423, loss_seg_dice : 3.048184
#
#
# dice score (1-dice_loss): 0.559
# dice score (1-dice_loss): 0.131
# dice score (1-dice_loss): 0.163
# dice score (1-dice_loss): 0.068
# dicetotal:3.078
# iteration 2 : loss : 2.213461, loss_seg : 1.348560, loss_seg_dice : 3.078361
#
#
# dice score (1-dice_loss): 0.574
# dice score (1-dice_loss): 0.104
# dice score (1-dice_loss): 0.230
# dice score (1-dice_loss): 0.061
# dicetotal:3.032
# iteration 3 : loss : 2.138057, loss_seg : 1.244435, loss_seg_dice : 3.031679
#
#
# dice score (1-dice_loss): 0.573
# dice score (1-dice_loss): 0.145
# dice score (1-dice_loss): 0.289
# dice score (1-dice_loss): 0.104
# dicetotal:2.890
# iteration 4 : loss : 2.073422, loss_seg : 1.257257, loss_seg_dice : 2.889586
#   0%|                              | 1/1501 [00:12<5:00:04, 12.00s/it]
# dice score (1-dice_loss): 0.590
# dice score (1-dice_loss): 0.107
# dice score (1-dice_loss): 0.284
# dice score (1-dice_loss): 0.107
# dicetotal:2.912
# iteration 5 : loss : 2.085508, loss_seg : 1.259200, loss_seg_dice : 2.911816
#
#
# dice score (1-dice_loss): 0.653
# dice score (1-dice_loss): 0.099
# dice score (1-dice_loss): 0.401
# dice score (1-dice_loss): 0.117
# dicetotal:2.730
# iteration 6 : loss : 1.933703, loss_seg : 1.137025, loss_seg_dice : 2.730381
#
#
# dice score (1-dice_loss): 0.571
# dice score (1-dice_loss): 0.170
# dice score (1-dice_loss): 0.273
# dice score (1-dice_loss): 0.100
# dicetotal:2.885
# iteration 7 : loss : 2.124408, loss_seg : 1.363865, loss_seg_dice : 2.884950
#
#
# dice score (1-dice_loss): 0.630
# dice score (1-dice_loss): 0.069
# dice score (1-dice_loss): 0.353
# dice score (1-dice_loss): 0.053
# dicetotal:2.896
# iteration 8 : loss : 1.988268, loss_seg : 1.080730, loss_seg_dice : 2.895805
#   0%|                              | 2/1501 [00:23<4:57:21, 11.90s/it]
# dice score (1-dice_loss): 0.669
# dice score (1-dice_loss): 0.199
# dice score (1-dice_loss): 0.344
# dice score (1-dice_loss): 0.130
# dicetotal:2.657
# iteration 9 : loss : 1.895708, loss_seg : 1.133924, loss_seg_dice : 2.657492
#
#
# dice score (1-dice_loss): 0.683
# dice score (1-dice_loss): 0.094
# dice score (1-dice_loss): 0.388
# dice score (1-dice_loss): 0.090
# dicetotal:2.745
# iteration 10 : loss : 1.903102, loss_seg : 1.060963, loss_seg_dice : 2.745241
#
#
# dice score (1-dice_loss): 0.691
# dice score (1-dice_loss): 0.175
# dice score (1-dice_loss): 0.335
# dice score (1-dice_loss): 0.102
# dicetotal:2.697
# iteration 11 : loss : 1.892551, loss_seg : 1.088109, loss_seg_dice : 2.696992
#
#
# dice score (1-dice_loss): 0.753
# dice score (1-dice_loss): 0.110
# dice score (1-dice_loss): 0.393
# dice score (1-dice_loss): 0.064
# dicetotal:2.681
# iteration 12 : loss : 1.800328, loss_seg : 0.919907, loss_seg_dice : 2.680750
#   0%|                              | 3/1501 [00:35<4:55:30, 11.84s/it]
# dice score (1-dice_loss): 0.762
# dice score (1-dice_loss): 0.138
# dice score (1-dice_loss): 0.476
# dice score (1-dice_loss): 0.094
# dicetotal:2.530
# iteration 13 : loss : 1.732750, loss_seg : 0.935953, loss_seg_dice : 2.529547
#
#
# dice score (1-dice_loss): 0.771
# dice score (1-dice_loss): 0.113
# dice score (1-dice_loss): 0.417
# dice score (1-dice_loss): 0.081
# dicetotal:2.618
# iteration 14 : loss : 1.771730, loss_seg : 0.925174, loss_seg_dice : 2.618286
#
#
# dice score (1-dice_loss): 0.783
# dice score (1-dice_loss): 0.152
# dice score (1-dice_loss): 0.359
# dice score (1-dice_loss): 0.135
# dicetotal:2.571
# iteration 15 : loss : 1.828175, loss_seg : 1.085436, loss_seg_dice : 2.570913
#
#
# dice score (1-dice_loss): 0.810
# dice score (1-dice_loss): 0.141
# dice score (1-dice_loss): 0.449
# dice score (1-dice_loss): 0.109
# dicetotal:2.491
# iteration 16 : loss : 1.726404, loss_seg : 0.962276, loss_seg_dice : 2.490533
#   0%|                              | 4/1501 [00:46<4:52:17, 11.71s/it]
# dice score (1-dice_loss): 0.825
# dice score (1-dice_loss): 0.201
# dice score (1-dice_loss): 0.477
# dice score (1-dice_loss): 0.066
# dicetotal:2.431
# iteration 17 : loss : 1.641185, loss_seg : 0.851119, loss_seg_dice : 2.431251
#
#
# dice score (1-dice_loss): 0.811
# dice score (1-dice_loss): 0.156
# dice score (1-dice_loss): 0.452
# dice score (1-dice_loss): 0.106
# dicetotal:2.476
# iteration 18 : loss : 1.701442, loss_seg : 0.926871, loss_seg_dice : 2.476013
#
#
# dice score (1-dice_loss): 0.845
# dice score (1-dice_loss): 0.202
# dice score (1-dice_loss): 0.424
# dice score (1-dice_loss): 0.123
# dicetotal:2.406
# iteration 19 : loss : 1.651720, loss_seg : 0.897491, loss_seg_dice : 2.405949
#
#
# dice score (1-dice_loss): 0.894
# dice score (1-dice_loss): 0.166
# dice score (1-dice_loss): 0.544
# dice score (1-dice_loss): 0.105
# dicetotal:2.290
# iteration 20 : loss : 1.501622, loss_seg : 0.713033, loss_seg_dice : 2.290212
#   0%|                              | 5/1501 [00:59<4:56:37, 11.90s/it]
# dice score (1-dice_loss): 0.859
# dice score (1-dice_loss): 0.202
# dice score (1-dice_loss): 0.443
# dice score (1-dice_loss): 0.132
# dicetotal:2.364
# iteration 21 : loss : 1.652783, loss_seg : 0.941308, loss_seg_dice : 2.364258
#
#
# dice score (1-dice_loss): 0.897
# dice score (1-dice_loss): 0.107
# dice score (1-dice_loss): 0.544
# dice score (1-dice_loss): 0.095
# dicetotal:2.357
# iteration 22 : loss : 1.497911, loss_seg : 0.638758, loss_seg_dice : 2.357064
#
#
# dice score (1-dice_loss): 0.915
# dice score (1-dice_loss): 0.235
# dice score (1-dice_loss): 0.512
# dice score (1-dice_loss): 0.139
# dicetotal:2.199
# iteration 23 : loss : 1.491412, loss_seg : 0.783422, loss_seg_dice : 2.199401
#
#
# dice score (1-dice_loss): 0.907
# dice score (1-dice_loss): 0.198
# dice score (1-dice_loss): 0.449
# dice score (1-dice_loss): 0.121
# dicetotal:2.325
# iteration 24 : loss : 1.578270, loss_seg : 0.831448, loss_seg_dice : 2.325092
#   0%|                              | 6/1501 [01:11<4:57:17, 11.93s/it]
# dice score (1-dice_loss): 0.918
# dice score (1-dice_loss): 0.176
# dice score (1-dice_loss): 0.490
# dice score (1-dice_loss): 0.125
# dicetotal:2.291
# iteration 25 : loss : 1.547593, loss_seg : 0.804573, loss_seg_dice : 2.290613
#
#
# dice score (1-dice_loss): 0.919
# dice score (1-dice_loss): 0.165
# dice score (1-dice_loss): 0.480
# dice score (1-dice_loss): 0.150
# dicetotal:2.286
# iteration 26 : loss : 1.525127, loss_seg : 0.763865, loss_seg_dice : 2.286390
#
#
# dice score (1-dice_loss): 0.932
# dice score (1-dice_loss): 0.213
# dice score (1-dice_loss): 0.569
# dice score (1-dice_loss): 0.187
# dicetotal:2.098
# iteration 27 : loss : 1.435590, loss_seg : 0.773612, loss_seg_dice : 2.097567
#
#
# dice score (1-dice_loss): 0.936
# dice score (1-dice_loss): 0.217
# dice score (1-dice_loss): 0.476
# dice score (1-dice_loss): 0.156
# dicetotal:2.216
# iteration 28 : loss : 1.488240, loss_seg : 0.760945, loss_seg_dice : 2.215534
#   0%|▏                             | 7/1501 [01:22<4:55:27, 11.87s/it]
# dice score (1-dice_loss): 0.937
# dice score (1-dice_loss): 0.176
# dice score (1-dice_loss): 0.545
# dice score (1-dice_loss): 0.110
# dicetotal:2.231
# iteration 29 : loss : 1.439321, loss_seg : 0.647399, loss_seg_dice : 2.231243
#
#
# dice score (1-dice_loss): 0.917
# dice score (1-dice_loss): 0.132
# dice score (1-dice_loss): 0.544
# dice score (1-dice_loss): 0.159
# dicetotal:2.248
# iteration 30 : loss : 1.492079, loss_seg : 0.735971, loss_seg_dice : 2.248188
#
#
# dice score (1-dice_loss): 0.945
# dice score (1-dice_loss): 0.233
# dice score (1-dice_loss): 0.494
# dice score (1-dice_loss): 0.200
# dicetotal:2.128
# iteration 31 : loss : 1.443653, loss_seg : 0.759192, loss_seg_dice : 2.128113
#
#
# dice score (1-dice_loss): 0.937
# dice score (1-dice_loss): 0.232
# dice score (1-dice_loss): 0.559
# dice score (1-dice_loss): 0.122
# dicetotal:2.150
# iteration 32 : loss : 1.417694, loss_seg : 0.684917, loss_seg_dice : 2.150471
#   1%|▏                             | 8/1501 [01:34<4:54:21, 11.83s/it]
# dice score (1-dice_loss): 0.947
# dice score (1-dice_loss): 0.245
# dice score (1-dice_loss): 0.549
# dice score (1-dice_loss): 0.178
# dicetotal:2.081
# iteration 33 : loss : 1.414588, loss_seg : 0.748331, loss_seg_dice : 2.080846
#
#
# dice score (1-dice_loss): 0.941
# dice score (1-dice_loss): 0.237
# dice score (1-dice_loss): 0.499
# dice score (1-dice_loss): 0.201
# dicetotal:2.121
# iteration 34 : loss : 1.499867, loss_seg : 0.878419, loss_seg_dice : 2.121315
#
#
# dice score (1-dice_loss): 0.946
# dice score (1-dice_loss): 0.216
# dice score (1-dice_loss): 0.585
# dice score (1-dice_loss): 0.196
# dicetotal:2.058
# iteration 35 : loss : 1.401482, loss_seg : 0.745249, loss_seg_dice : 2.057714
#
#
# dice score (1-dice_loss): 0.940
# dice score (1-dice_loss): 0.260
# dice score (1-dice_loss): 0.609
# dice score (1-dice_loss): 0.141
# dicetotal:2.050
# iteration 36 : loss : 1.346971, loss_seg : 0.644346, loss_seg_dice : 2.049596
#   1%|▏                             | 9/1501 [01:46<4:54:17, 11.83s/it]
# dice score (1-dice_loss): 0.942
# dice score (1-dice_loss): 0.263
# dice score (1-dice_loss): 0.553
# dice score (1-dice_loss): 0.182
# dicetotal:2.060
# iteration 37 : loss : 1.381790, loss_seg : 0.703580, loss_seg_dice : 2.060000
#
#
# dice score (1-dice_loss): 0.947
# dice score (1-dice_loss): 0.251
# dice score (1-dice_loss): 0.543
# dice score (1-dice_loss): 0.208
# dicetotal:2.051
# iteration 38 : loss : 1.347097, loss_seg : 0.643147, loss_seg_dice : 2.051047
#
#
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.269
# dice score (1-dice_loss): 0.532
# dice score (1-dice_loss): 0.225
# dicetotal:2.018
# iteration 39 : loss : 1.382082, loss_seg : 0.746200, loss_seg_dice : 2.017965
#
#
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.297
# dice score (1-dice_loss): 0.497
# dice score (1-dice_loss): 0.238
# dicetotal:2.013
# iteration 40 : loss : 1.361657, loss_seg : 0.710393, loss_seg_dice : 2.012922
#   1%|▏                            | 10/1501 [01:58<4:54:47, 11.86s/it]
# dice score (1-dice_loss): 0.951
# dice score (1-dice_loss): 0.283
# dice score (1-dice_loss): 0.508
# dice score (1-dice_loss): 0.247
# dicetotal:2.011
# iteration 41 : loss : 1.432786, loss_seg : 0.855062, loss_seg_dice : 2.010509
#
#
# dice score (1-dice_loss): 0.951
# dice score (1-dice_loss): 0.293
# dice score (1-dice_loss): 0.535
# dice score (1-dice_loss): 0.229
# dicetotal:1.992
# iteration 42 : loss : 1.338028, loss_seg : 0.684408, loss_seg_dice : 1.991647
#
#
# dice score (1-dice_loss): 0.947
# dice score (1-dice_loss): 0.240
# dice score (1-dice_loss): 0.543
# dice score (1-dice_loss): 0.178
# dicetotal:2.091
# iteration 43 : loss : 1.359688, loss_seg : 0.627929, loss_seg_dice : 2.091446
#
#
# dice score (1-dice_loss): 0.956
# dice score (1-dice_loss): 0.322
# dice score (1-dice_loss): 0.583
# dice score (1-dice_loss): 0.178
# dicetotal:1.961
# iteration 44 : loss : 1.246135, loss_seg : 0.530833, loss_seg_dice : 1.961437
#   1%|▏                            | 11/1501 [02:10<4:54:58, 11.88s/it]
# dice score (1-dice_loss): 0.965
# dice score (1-dice_loss): 0.308
# dice score (1-dice_loss): 0.473
# dice score (1-dice_loss): 0.207
# dicetotal:2.047
# iteration 45 : loss : 1.305815, loss_seg : 0.564863, loss_seg_dice : 2.046767
#
#
# dice score (1-dice_loss): 0.963
# dice score (1-dice_loss): 0.308
# dice score (1-dice_loss): 0.600
# dice score (1-dice_loss): 0.175
# dicetotal:1.954
# iteration 46 : loss : 1.248747, loss_seg : 0.543211, loss_seg_dice : 1.954283
#
#
# dice score (1-dice_loss): 0.967
# dice score (1-dice_loss): 0.292
# dice score (1-dice_loss): 0.602
# dice score (1-dice_loss): 0.208
# dicetotal:1.930
# iteration 47 : loss : 1.265030, loss_seg : 0.599605, loss_seg_dice : 1.930454
#
#
# dice score (1-dice_loss): 0.948
# dice score (1-dice_loss): 0.318
# dice score (1-dice_loss): 0.519
# dice score (1-dice_loss): 0.183
# dicetotal:2.031
# iteration 48 : loss : 1.392262, loss_seg : 0.753097, loss_seg_dice : 2.031428
#   1%|▏                            | 12/1501 [02:22<4:54:08, 11.85s/it]
# dice score (1-dice_loss): 0.947
# dice score (1-dice_loss): 0.269
# dice score (1-dice_loss): 0.605
# dice score (1-dice_loss): 0.168
# dicetotal:2.011
# iteration 49 : loss : 1.313278, loss_seg : 0.615477, loss_seg_dice : 2.011079
#
#
# dice score (1-dice_loss): 0.964
# dice score (1-dice_loss): 0.272
# dice score (1-dice_loss): 0.595
# dice score (1-dice_loss): 0.202
# dicetotal:1.967
# iteration 50 : loss : 1.252540, loss_seg : 0.537786, loss_seg_dice : 1.967294
#
#
# dice score (1-dice_loss): 0.967
# dice score (1-dice_loss): 0.296
# dice score (1-dice_loss): 0.628
# dice score (1-dice_loss): 0.216
# dicetotal:1.892
# iteration 51 : loss : 1.245954, loss_seg : 0.599704, loss_seg_dice : 1.892204
#
#
# dice score (1-dice_loss): 0.965
# dice score (1-dice_loss): 0.318
# dice score (1-dice_loss): 0.600
# dice score (1-dice_loss): 0.237
# dicetotal:1.879
# iteration 52 : loss : 1.237752, loss_seg : 0.596110, loss_seg_dice : 1.879395
#   1%|▎                            | 13/1501 [02:34<4:56:53, 11.97s/it]
# dice score (1-dice_loss): 0.968
# dice score (1-dice_loss): 0.315
# dice score (1-dice_loss): 0.604
# dice score (1-dice_loss): 0.181
# dicetotal:1.931
# iteration 53 : loss : 1.214787, loss_seg : 0.498208, loss_seg_dice : 1.931366
#
#
# dice score (1-dice_loss): 0.959
# dice score (1-dice_loss): 0.270
# dice score (1-dice_loss): 0.596
# dice score (1-dice_loss): 0.186
# dicetotal:1.988
# iteration 54 : loss : 1.273757, loss_seg : 0.559090, loss_seg_dice : 1.988424
#
#
# dice score (1-dice_loss): 0.960
# dice score (1-dice_loss): 0.310
# dice score (1-dice_loss): 0.627
# dice score (1-dice_loss): 0.188
# dicetotal:1.916
# iteration 55 : loss : 1.227641, loss_seg : 0.539318, loss_seg_dice : 1.915964
#
#
# dice score (1-dice_loss): 0.972
# dice score (1-dice_loss): 0.327
# dice score (1-dice_loss): 0.650
# dice score (1-dice_loss): 0.236
# dicetotal:1.816
# iteration 56 : loss : 1.157624, loss_seg : 0.499503, loss_seg_dice : 1.815745
#   1%|▎                            | 14/1501 [02:45<4:54:27, 11.88s/it]
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.270
# dice score (1-dice_loss): 0.537
# dice score (1-dice_loss): 0.166
# dicetotal:2.072
# iteration 57 : loss : 1.413500, loss_seg : 0.754819, loss_seg_dice : 2.072181
#
#
# dice score (1-dice_loss): 0.953
# dice score (1-dice_loss): 0.297
# dice score (1-dice_loss): 0.604
# dice score (1-dice_loss): 0.204
# dicetotal:1.941
# iteration 58 : loss : 1.280844, loss_seg : 0.620260, loss_seg_dice : 1.941428
#
#
# dice score (1-dice_loss): 0.964
# dice score (1-dice_loss): 0.250
# dice score (1-dice_loss): 0.500
# dice score (1-dice_loss): 0.221
# dicetotal:2.065
# iteration 59 : loss : 1.353664, loss_seg : 0.641890, loss_seg_dice : 2.065439
#
#
# dice score (1-dice_loss): 0.964
# dice score (1-dice_loss): 0.260
# dice score (1-dice_loss): 0.542
# dice score (1-dice_loss): 0.227
# dicetotal:2.008
# iteration 60 : loss : 1.365291, loss_seg : 0.722872, loss_seg_dice : 2.007710
#   1%|▎                            | 15/1501 [02:57<4:53:44, 11.86s/it]
# dice score (1-dice_loss): 0.967
# dice score (1-dice_loss): 0.373
# dice score (1-dice_loss): 0.550
# dice score (1-dice_loss): 0.180
# dicetotal:1.929
# iteration 61 : loss : 1.248072, loss_seg : 0.566958, loss_seg_dice : 1.929186
#
#
# dice score (1-dice_loss): 0.963
# dice score (1-dice_loss): 0.323
# dice score (1-dice_loss): 0.608
# dice score (1-dice_loss): 0.236
# dicetotal:1.869
# iteration 62 : loss : 1.233952, loss_seg : 0.598882, loss_seg_dice : 1.869022
#
#
# dice score (1-dice_loss): 0.961
# dice score (1-dice_loss): 0.354
# dice score (1-dice_loss): 0.520
# dice score (1-dice_loss): 0.256
# dicetotal:1.908
# iteration 63 : loss : 1.288031, loss_seg : 0.668210, loss_seg_dice : 1.907851
#
#
# dice score (1-dice_loss): 0.960
# dice score (1-dice_loss): 0.304
# dice score (1-dice_loss): 0.596
# dice score (1-dice_loss): 0.210
# dicetotal:1.930
# iteration 64 : loss : 1.298306, loss_seg : 0.666271, loss_seg_dice : 1.930341
#   1%|▎                            | 16/1501 [03:09<4:52:12, 11.81s/it]
# dice score (1-dice_loss): 0.956
# dice score (1-dice_loss): 0.347
# dice score (1-dice_loss): 0.645
# dice score (1-dice_loss): 0.206
# dicetotal:1.846
# iteration 65 : loss : 1.199826, loss_seg : 0.554100, loss_seg_dice : 1.845551
#
#
# dice score (1-dice_loss): 0.971
# dice score (1-dice_loss): 0.341
# dice score (1-dice_loss): 0.661
# dice score (1-dice_loss): 0.216
# dicetotal:1.810
# iteration 66 : loss : 1.160967, loss_seg : 0.511726, loss_seg_dice : 1.810207
#
#
# dice score (1-dice_loss): 0.962
# dice score (1-dice_loss): 0.288
# dice score (1-dice_loss): 0.580
# dice score (1-dice_loss): 0.235
# dicetotal:1.934
# iteration 67 : loss : 1.299849, loss_seg : 0.665361, loss_seg_dice : 1.934337
#
#
# dice score (1-dice_loss): 0.969
# dice score (1-dice_loss): 0.372
# dice score (1-dice_loss): 0.581
# dice score (1-dice_loss): 0.279
# dicetotal:1.799
# iteration 68 : loss : 1.210232, loss_seg : 0.621532, loss_seg_dice : 1.798931
#   1%|▎                            | 17/1501 [03:21<4:52:47, 11.84s/it]
# dice score (1-dice_loss): 0.965
# dice score (1-dice_loss): 0.352
# dice score (1-dice_loss): 0.624
# dice score (1-dice_loss): 0.196
# dicetotal:1.864
# iteration 69 : loss : 1.214764, loss_seg : 0.565552, loss_seg_dice : 1.863975
#
#
# dice score (1-dice_loss): 0.961
# dice score (1-dice_loss): 0.382
# dice score (1-dice_loss): 0.517
# dice score (1-dice_loss): 0.177
# dicetotal:1.963
# iteration 70 : loss : 1.293786, loss_seg : 0.624092, loss_seg_dice : 1.963481
#
#
# dice score (1-dice_loss): 0.968
# dice score (1-dice_loss): 0.316
# dice score (1-dice_loss): 0.569
# dice score (1-dice_loss): 0.281
# dicetotal:1.865
# iteration 71 : loss : 1.192438, loss_seg : 0.519763, loss_seg_dice : 1.865114
#
#
# dice score (1-dice_loss): 0.969
# dice score (1-dice_loss): 0.400
# dice score (1-dice_loss): 0.598
# dice score (1-dice_loss): 0.242
# dicetotal:1.792
# iteration 72 : loss : 1.167371, loss_seg : 0.542987, loss_seg_dice : 1.791755
#   1%|▎                            | 18/1501 [03:33<4:51:30, 11.79s/it]
# dice score (1-dice_loss): 0.966
# dice score (1-dice_loss): 0.401
# dice score (1-dice_loss): 0.562
# dice score (1-dice_loss): 0.285
# dicetotal:1.785
# iteration 73 : loss : 1.200423, loss_seg : 0.615382, loss_seg_dice : 1.785464
#
#
# dice score (1-dice_loss): 0.972
# dice score (1-dice_loss): 0.310
# dice score (1-dice_loss): 0.587
# dice score (1-dice_loss): 0.199
# dicetotal:1.933
# iteration 74 : loss : 1.191786, loss_seg : 0.450711, loss_seg_dice : 1.932861
#
#
# dice score (1-dice_loss): 0.961
# dice score (1-dice_loss): 0.324
# dice score (1-dice_loss): 0.633
# dice score (1-dice_loss): 0.213
# dicetotal:1.867
# iteration 75 : loss : 1.250741, loss_seg : 0.634179, loss_seg_dice : 1.867303
#
#
# dice score (1-dice_loss): 0.969
# dice score (1-dice_loss): 0.365
# dice score (1-dice_loss): 0.650
# dice score (1-dice_loss): 0.239
# dicetotal:1.778
# iteration 76 : loss : 1.176638, loss_seg : 0.575660, loss_seg_dice : 1.777615
#   1%|▎                            | 19/1501 [03:45<4:52:29, 11.84s/it]
# dice score (1-dice_loss): 0.964
# dice score (1-dice_loss): 0.381
# dice score (1-dice_loss): 0.491
# dice score (1-dice_loss): 0.231
# dicetotal:1.934
# iteration 77 : loss : 1.330011, loss_seg : 0.726138, loss_seg_dice : 1.933883
#
#
# dice score (1-dice_loss): 0.964
# dice score (1-dice_loss): 0.334
# dice score (1-dice_loss): 0.584
# dice score (1-dice_loss): 0.218
# dicetotal:1.900
# iteration 78 : loss : 1.267219, loss_seg : 0.634351, loss_seg_dice : 1.900086
#
#
# dice score (1-dice_loss): 0.956
# dice score (1-dice_loss): 0.390
# dice score (1-dice_loss): 0.582
# dice score (1-dice_loss): 0.245
# dicetotal:1.826
# iteration 79 : loss : 1.231859, loss_seg : 0.637390, loss_seg_dice : 1.826328
#
#
# dice score (1-dice_loss): 0.966
# dice score (1-dice_loss): 0.437
# dice score (1-dice_loss): 0.570
# dice score (1-dice_loss): 0.234
# dicetotal:1.793
# iteration 80 : loss : 1.186138, loss_seg : 0.578824, loss_seg_dice : 1.793452
#   1%|▍                            | 20/1501 [03:56<4:52:38, 11.86s/it]
# dice score (1-dice_loss): 0.958
# dice score (1-dice_loss): 0.368
# dice score (1-dice_loss): 0.552
# dice score (1-dice_loss): 0.206
# dicetotal:1.916
# iteration 81 : loss : 1.266287, loss_seg : 0.616470, loss_seg_dice : 1.916104
#
#
# dice score (1-dice_loss): 0.962
# dice score (1-dice_loss): 0.316
# dice score (1-dice_loss): 0.563
# dice score (1-dice_loss): 0.209
# dicetotal:1.950
# iteration 82 : loss : 1.272731, loss_seg : 0.595162, loss_seg_dice : 1.950300
#
#
# dice score (1-dice_loss): 0.967
# dice score (1-dice_loss): 0.386
# dice score (1-dice_loss): 0.566
# dice score (1-dice_loss): 0.262
# dicetotal:1.819
# iteration 83 : loss : 1.229133, loss_seg : 0.638849, loss_seg_dice : 1.819416
#
#
# dice score (1-dice_loss): 0.964
# dice score (1-dice_loss): 0.418
# dice score (1-dice_loss): 0.611
# dice score (1-dice_loss): 0.248
# dicetotal:1.759
# iteration 84 : loss : 1.166660, loss_seg : 0.574327, loss_seg_dice : 1.758993
#   1%|▍                            | 21/1501 [04:08<4:53:07, 11.88s/it]
# dice score (1-dice_loss): 0.966
# dice score (1-dice_loss): 0.257
# dice score (1-dice_loss): 0.559
# dice score (1-dice_loss): 0.200
# dicetotal:2.018
# iteration 85 : loss : 1.329493, loss_seg : 0.641104, loss_seg_dice : 2.017882
#
#
# dice score (1-dice_loss): 0.969
# dice score (1-dice_loss): 0.333
# dice score (1-dice_loss): 0.576
# dice score (1-dice_loss): 0.254
# dicetotal:1.868
# iteration 86 : loss : 1.233175, loss_seg : 0.598213, loss_seg_dice : 1.868137
#
#
# dice score (1-dice_loss): 0.960
# dice score (1-dice_loss): 0.430
# dice score (1-dice_loss): 0.571
# dice score (1-dice_loss): 0.215
# dicetotal:1.824
# iteration 87 : loss : 1.205122, loss_seg : 0.586020, loss_seg_dice : 1.824224
#
#
# dice score (1-dice_loss): 0.974
# dice score (1-dice_loss): 0.387
# dice score (1-dice_loss): 0.682
# dice score (1-dice_loss): 0.274
# dicetotal:1.683
# iteration 88 : loss : 1.085408, loss_seg : 0.488126, loss_seg_dice : 1.682690
#   1%|▍                            | 22/1501 [04:20<4:53:17, 11.90s/it]
# dice score (1-dice_loss): 0.966
# dice score (1-dice_loss): 0.443
# dice score (1-dice_loss): 0.593
# dice score (1-dice_loss): 0.227
# dicetotal:1.771
# iteration 89 : loss : 1.173588, loss_seg : 0.576116, loss_seg_dice : 1.771061
#
#
# dice score (1-dice_loss): 0.976
# dice score (1-dice_loss): 0.469
# dice score (1-dice_loss): 0.623
# dice score (1-dice_loss): 0.288
# dicetotal:1.644
# iteration 90 : loss : 1.105024, loss_seg : 0.565670, loss_seg_dice : 1.644378
#
#
# dice score (1-dice_loss): 0.966
# dice score (1-dice_loss): 0.327
# dice score (1-dice_loss): 0.642
# dice score (1-dice_loss): 0.192
# dicetotal:1.874
# iteration 91 : loss : 1.164586, loss_seg : 0.455568, loss_seg_dice : 1.873604
#
#
# dice score (1-dice_loss): 0.973
# dice score (1-dice_loss): 0.380
# dice score (1-dice_loss): 0.614
# dice score (1-dice_loss): 0.227
# dicetotal:1.806
# iteration 92 : loss : 1.174162, loss_seg : 0.541833, loss_seg_dice : 1.806492
#   2%|▍                            | 23/1501 [04:32<4:48:36, 11.72s/it]
# dice score (1-dice_loss): 0.956
# dice score (1-dice_loss): 0.447
# dice score (1-dice_loss): 0.516
# dice score (1-dice_loss): 0.250
# dicetotal:1.831
# iteration 93 : loss : 1.259619, loss_seg : 0.688495, loss_seg_dice : 1.830744
#
#
# dice score (1-dice_loss): 0.969
# dice score (1-dice_loss): 0.360
# dice score (1-dice_loss): 0.640
# dice score (1-dice_loss): 0.239
# dicetotal:1.791
# iteration 94 : loss : 1.195126, loss_seg : 0.598756, loss_seg_dice : 1.791496
#
#
# dice score (1-dice_loss): 0.974
# dice score (1-dice_loss): 0.446
# dice score (1-dice_loss): 0.646
# dice score (1-dice_loss): 0.210
# dicetotal:1.724
# iteration 95 : loss : 1.104023, loss_seg : 0.484473, loss_seg_dice : 1.723573
#
#
# dice score (1-dice_loss): 0.977
# dice score (1-dice_loss): 0.375
# dice score (1-dice_loss): 0.619
# dice score (1-dice_loss): 0.250
# dicetotal:1.778
# iteration 96 : loss : 1.152344, loss_seg : 0.526891, loss_seg_dice : 1.777797
#   2%|▍                            | 24/1501 [04:44<4:51:42, 11.85s/it]
# dice score (1-dice_loss): 0.971
# dice score (1-dice_loss): 0.441
# dice score (1-dice_loss): 0.567
# dice score (1-dice_loss): 0.242
# dicetotal:1.780
# iteration 97 : loss : 1.150331, loss_seg : 0.520999, loss_seg_dice : 1.779663
#
#
# dice score (1-dice_loss): 0.964
# dice score (1-dice_loss): 0.454
# dice score (1-dice_loss): 0.675
# dice score (1-dice_loss): 0.228
# dicetotal:1.680
# iteration 98 : loss : 1.084263, loss_seg : 0.489000, loss_seg_dice : 1.679526
#
#
# dice score (1-dice_loss): 0.974
# dice score (1-dice_loss): 0.411
# dice score (1-dice_loss): 0.598
# dice score (1-dice_loss): 0.244
# dicetotal:1.774
# iteration 99 : loss : 1.181680, loss_seg : 0.589735, loss_seg_dice : 1.773626
#
#
# dice score (1-dice_loss): 0.978
# dice score (1-dice_loss): 0.466
# dice score (1-dice_loss): 0.621
# dice score (1-dice_loss): 0.260
# dicetotal:1.676
# iteration 100 : loss : 1.065028, loss_seg : 0.454455, loss_seg_dice : 1.675601
#   2%|▍                            | 25/1501 [04:55<4:48:42, 11.74s/it]
# dice score (1-dice_loss): 0.970
# dice score (1-dice_loss): 0.479
# dice score (1-dice_loss): 0.564
# dice score (1-dice_loss): 0.213
# dicetotal:1.774
# iteration 101 : loss : 1.165318, loss_seg : 0.556468, loss_seg_dice : 1.774168
#
#
# dice score (1-dice_loss): 0.968
# dice score (1-dice_loss): 0.470
# dice score (1-dice_loss): 0.539
# dice score (1-dice_loss): 0.223
# dicetotal:1.801
# iteration 102 : loss : 1.245659, loss_seg : 0.690454, loss_seg_dice : 1.800865
#
#
# dice score (1-dice_loss): 0.974
# dice score (1-dice_loss): 0.439
# dice score (1-dice_loss): 0.628
# dice score (1-dice_loss): 0.285
# dicetotal:1.674
# iteration 103 : loss : 1.097063, loss_seg : 0.520015, loss_seg_dice : 1.674111
#
#
# dice score (1-dice_loss): 0.972
# dice score (1-dice_loss): 0.446
# dice score (1-dice_loss): 0.644
# dice score (1-dice_loss): 0.239
# dicetotal:1.700
# iteration 104 : loss : 1.080600, loss_seg : 0.461081, loss_seg_dice : 1.700120
#   2%|▌                            | 26/1501 [05:07<4:46:48, 11.67s/it]
# dice score (1-dice_loss): 0.977
# dice score (1-dice_loss): 0.499
# dice score (1-dice_loss): 0.632
# dice score (1-dice_loss): 0.251
# dicetotal:1.642
# iteration 105 : loss : 1.082027, loss_seg : 0.521664, loss_seg_dice : 1.642391
#
#
# dice score (1-dice_loss): 0.947
# dice score (1-dice_loss): 0.443
# dice score (1-dice_loss): 0.511
# dice score (1-dice_loss): 0.226
# dicetotal:1.872
# iteration 106 : loss : 1.313920, loss_seg : 0.755382, loss_seg_dice : 1.872458
#
#
# dice score (1-dice_loss): 0.974
# dice score (1-dice_loss): 0.481
# dice score (1-dice_loss): 0.641
# dice score (1-dice_loss): 0.250
# dicetotal:1.655
# iteration 107 : loss : 1.078023, loss_seg : 0.500719, loss_seg_dice : 1.655327
#
#
# dice score (1-dice_loss): 0.973
# dice score (1-dice_loss): 0.394
# dice score (1-dice_loss): 0.650
# dice score (1-dice_loss): 0.198
# dicetotal:1.786
# iteration 108 : loss : 1.093142, loss_seg : 0.400477, loss_seg_dice : 1.785807
#   2%|▌                            | 27/1501 [05:18<4:47:07, 11.69s/it]
# dice score (1-dice_loss): 0.975
# dice score (1-dice_loss): 0.319
# dice score (1-dice_loss): 0.766
# dice score (1-dice_loss): 0.268
# dicetotal:1.672
# iteration 109 : loss : 1.044953, loss_seg : 0.417596, loss_seg_dice : 1.672310
#
#
# dice score (1-dice_loss): 0.978
# dice score (1-dice_loss): 0.276
# dice score (1-dice_loss): 0.728
# dice score (1-dice_loss): 0.184
# dicetotal:1.834
# iteration 110 : loss : 1.115970, loss_seg : 0.397993, loss_seg_dice : 1.833947
#
#
# dice score (1-dice_loss): 0.975
# dice score (1-dice_loss): 0.465
# dice score (1-dice_loss): 0.630
# dice score (1-dice_loss): 0.308
# dicetotal:1.622
# iteration 111 : loss : 1.084877, loss_seg : 0.547590, loss_seg_dice : 1.622164
#
#
# dice score (1-dice_loss): 0.983
# dice score (1-dice_loss): 0.493
# dice score (1-dice_loss): 0.682
# dice score (1-dice_loss): 0.277
# dicetotal:1.565
# iteration 112 : loss : 0.999549, loss_seg : 0.434580, loss_seg_dice : 1.564519
#   2%|▌                            | 28/1501 [05:31<4:51:37, 11.88s/it]
# dice score (1-dice_loss): 0.980
# dice score (1-dice_loss): 0.374
# dice score (1-dice_loss): 0.574
# dice score (1-dice_loss): 0.286
# dicetotal:1.786
# iteration 113 : loss : 1.155942, loss_seg : 0.525860, loss_seg_dice : 1.786025
#
#
# dice score (1-dice_loss): 0.963
# dice score (1-dice_loss): 0.425
# dice score (1-dice_loss): 0.575
# dice score (1-dice_loss): 0.181
# dicetotal:1.857
# iteration 114 : loss : 1.262606, loss_seg : 0.668651, loss_seg_dice : 1.856561
#
#
# dice score (1-dice_loss): 0.977
# dice score (1-dice_loss): 0.430
# dice score (1-dice_loss): 0.641
# dice score (1-dice_loss): 0.271
# dicetotal:1.681
# iteration 115 : loss : 1.097641, loss_seg : 0.514080, loss_seg_dice : 1.681201
#
#
# dice score (1-dice_loss): 0.971
# dice score (1-dice_loss): 0.416
# dice score (1-dice_loss): 0.532
# dice score (1-dice_loss): 0.227
# dicetotal:1.853
# iteration 116 : loss : 1.238152, loss_seg : 0.623535, loss_seg_dice : 1.852769
#   2%|▌                            | 29/1501 [05:43<4:50:52, 11.86s/it]
# dice score (1-dice_loss): 0.981
# dice score (1-dice_loss): 0.435
# dice score (1-dice_loss): 0.621
# dice score (1-dice_loss): 0.268
# dicetotal:1.696
# iteration 117 : loss : 1.051078, loss_seg : 0.406627, loss_seg_dice : 1.695529
#
#
# dice score (1-dice_loss): 0.975
# dice score (1-dice_loss): 0.480
# dice score (1-dice_loss): 0.656
# dice score (1-dice_loss): 0.298
# dicetotal:1.590
# iteration 118 : loss : 1.088056, loss_seg : 0.585753, loss_seg_dice : 1.590359
#
#
# dice score (1-dice_loss): 0.982
# dice score (1-dice_loss): 0.560
# dice score (1-dice_loss): 0.625
# dice score (1-dice_loss): 0.299
# dicetotal:1.533
# iteration 119 : loss : 0.991266, loss_seg : 0.449925, loss_seg_dice : 1.532608
#
#
# dice score (1-dice_loss): 0.975
# dice score (1-dice_loss): 0.480
# dice score (1-dice_loss): 0.641
# dice score (1-dice_loss): 0.258
# dicetotal:1.646
# iteration 120 : loss : 1.068596, loss_seg : 0.491157, loss_seg_dice : 1.646035
#   2%|▌                            | 30/1501 [05:55<4:52:05, 11.91s/it]
# dice score (1-dice_loss): 0.968
# dice score (1-dice_loss): 0.469
# dice score (1-dice_loss): 0.687
# dice score (1-dice_loss): 0.216
# dicetotal:1.660
# iteration 121 : loss : 1.082373, loss_seg : 0.504824, loss_seg_dice : 1.659922
#
#
# dice score (1-dice_loss): 0.976
# dice score (1-dice_loss): 0.511
# dice score (1-dice_loss): 0.695
# dice score (1-dice_loss): 0.241
# dicetotal:1.577
# iteration 122 : loss : 1.002383, loss_seg : 0.427507, loss_seg_dice : 1.577260
#
#
# dice score (1-dice_loss): 0.980
# dice score (1-dice_loss): 0.407
# dice score (1-dice_loss): 0.733
# dice score (1-dice_loss): 0.276
# dicetotal:1.603
# iteration 123 : loss : 1.030277, loss_seg : 0.457413, loss_seg_dice : 1.603142
#
#
# dice score (1-dice_loss): 0.968
# dice score (1-dice_loss): 0.398
# dice score (1-dice_loss): 0.696
# dice score (1-dice_loss): 0.228
# dicetotal:1.710
# iteration 124 : loss : 1.088334, loss_seg : 0.466874, loss_seg_dice : 1.709794
#   2%|▌                            | 31/1501 [06:07<4:53:27, 11.98s/it]
# dice score (1-dice_loss): 0.976
# dice score (1-dice_loss): 0.345
# dice score (1-dice_loss): 0.585
# dice score (1-dice_loss): 0.270
# dicetotal:1.825
# iteration 125 : loss : 1.210610, loss_seg : 0.596584, loss_seg_dice : 1.824636
#
#
# dice score (1-dice_loss): 0.966
# dice score (1-dice_loss): 0.446
# dice score (1-dice_loss): 0.555
# dice score (1-dice_loss): 0.215
# dicetotal:1.818
# iteration 126 : loss : 1.319144, loss_seg : 0.820601, loss_seg_dice : 1.817687
#
#
# dice score (1-dice_loss): 0.975
# dice score (1-dice_loss): 0.440
# dice score (1-dice_loss): 0.581
# dice score (1-dice_loss): 0.222
# dicetotal:1.782
# iteration 127 : loss : 1.190343, loss_seg : 0.599069, loss_seg_dice : 1.781616
#
#
# dice score (1-dice_loss): 0.983
# dice score (1-dice_loss): 0.446
# dice score (1-dice_loss): 0.701
# dice score (1-dice_loss): 0.312
# dicetotal:1.558
# iteration 128 : loss : 0.991627, loss_seg : 0.425230, loss_seg_dice : 1.558024
#   2%|▌                            | 32/1501 [06:19<4:54:06, 12.01s/it]
# dice score (1-dice_loss): 0.971
# dice score (1-dice_loss): 0.583
# dice score (1-dice_loss): 0.615
# dice score (1-dice_loss): 0.240
# dicetotal:1.591
# iteration 129 : loss : 1.065423, loss_seg : 0.540149, loss_seg_dice : 1.590696
#
#
# dice score (1-dice_loss): 0.975
# dice score (1-dice_loss): 0.520
# dice score (1-dice_loss): 0.578
# dice score (1-dice_loss): 0.178
# dicetotal:1.749
# iteration 130 : loss : 1.201733, loss_seg : 0.654710, loss_seg_dice : 1.748755
#
#
# dice score (1-dice_loss): 0.956
# dice score (1-dice_loss): 0.322
# dice score (1-dice_loss): 0.546
# dice score (1-dice_loss): 0.136
# dicetotal:2.039
# iteration 131 : loss : 1.305190, loss_seg : 0.571292, loss_seg_dice : 2.039088
#
#
# dice score (1-dice_loss): 0.977
# dice score (1-dice_loss): 0.442
# dice score (1-dice_loss): 0.688
# dice score (1-dice_loss): 0.286
# dicetotal:1.607
# iteration 132 : loss : 1.103822, loss_seg : 0.601061, loss_seg_dice : 1.606583
#   2%|▋                            | 33/1501 [06:31<4:51:51, 11.93s/it]
# dice score (1-dice_loss): 0.977
# dice score (1-dice_loss): 0.475
# dice score (1-dice_loss): 0.680
# dice score (1-dice_loss): 0.256
# dicetotal:1.612
# iteration 133 : loss : 1.064861, loss_seg : 0.517608, loss_seg_dice : 1.612114
#
#
# dice score (1-dice_loss): 0.973
# dice score (1-dice_loss): 0.492
# dice score (1-dice_loss): 0.600
# dice score (1-dice_loss): 0.292
# dicetotal:1.642
# iteration 134 : loss : 1.071466, loss_seg : 0.500939, loss_seg_dice : 1.641994
#
#
# dice score (1-dice_loss): 0.973
# dice score (1-dice_loss): 0.502
# dice score (1-dice_loss): 0.510
# dice score (1-dice_loss): 0.234
# dicetotal:1.782
# iteration 135 : loss : 1.154189, loss_seg : 0.526354, loss_seg_dice : 1.782023
#
#
# dice score (1-dice_loss): 0.977
# dice score (1-dice_loss): 0.510
# dice score (1-dice_loss): 0.629
# dice score (1-dice_loss): 0.310
# dicetotal:1.575
# iteration 136 : loss : 1.085213, loss_seg : 0.595735, loss_seg_dice : 1.574692
#   2%|▋                            | 34/1501 [06:42<4:47:23, 11.75s/it]
# dice score (1-dice_loss): 0.974
# dice score (1-dice_loss): 0.517
# dice score (1-dice_loss): 0.661
# dice score (1-dice_loss): 0.207
# dicetotal:1.641
# iteration 137 : loss : 1.071122, loss_seg : 0.501736, loss_seg_dice : 1.640507
#
#
# dice score (1-dice_loss): 0.975
# dice score (1-dice_loss): 0.505
# dice score (1-dice_loss): 0.592
# dice score (1-dice_loss): 0.272
# dicetotal:1.655
# iteration 138 : loss : 1.122639, loss_seg : 0.589999, loss_seg_dice : 1.655279
#
#
# dice score (1-dice_loss): 0.971
# dice score (1-dice_loss): 0.602
# dice score (1-dice_loss): 0.658
# dice score (1-dice_loss): 0.284
# dicetotal:1.485
# iteration 139 : loss : 0.976438, loss_seg : 0.467605, loss_seg_dice : 1.485271
#
#
# dice score (1-dice_loss): 0.969
# dice score (1-dice_loss): 0.523
# dice score (1-dice_loss): 0.741
# dice score (1-dice_loss): 0.279
# dicetotal:1.488
# iteration 140 : loss : 1.061011, loss_seg : 0.633892, loss_seg_dice : 1.488129
#   2%|▋                            | 35/1501 [06:54<4:50:18, 11.88s/it]
# dice score (1-dice_loss): 0.973
# dice score (1-dice_loss): 0.557
# dice score (1-dice_loss): 0.712
# dice score (1-dice_loss): 0.252
# dicetotal:1.506
# iteration 141 : loss : 0.949147, loss_seg : 0.392257, loss_seg_dice : 1.506036
#
#
# dice score (1-dice_loss): 0.964
# dice score (1-dice_loss): 0.379
# dice score (1-dice_loss): 0.609
# dice score (1-dice_loss): 0.236
# dicetotal:1.811
# iteration 142 : loss : 1.239914, loss_seg : 0.668805, loss_seg_dice : 1.811023
#
#
# dice score (1-dice_loss): 0.973
# dice score (1-dice_loss): 0.629
# dice score (1-dice_loss): 0.546
# dice score (1-dice_loss): 0.275
# dicetotal:1.577
# iteration 143 : loss : 1.064156, loss_seg : 0.550870, loss_seg_dice : 1.577442
#
#
# dice score (1-dice_loss): 0.974
# dice score (1-dice_loss): 0.488
# dice score (1-dice_loss): 0.706
# dice score (1-dice_loss): 0.281
# dicetotal:1.552
# iteration 144 : loss : 0.989542, loss_seg : 0.427462, loss_seg_dice : 1.551623
#   2%|▋                            | 36/1501 [07:06<4:49:08, 11.84s/it]
# dice score (1-dice_loss): 0.977
# dice score (1-dice_loss): 0.504
# dice score (1-dice_loss): 0.617
# dice score (1-dice_loss): 0.222
# dicetotal:1.679
# iteration 145 : loss : 1.075948, loss_seg : 0.473226, loss_seg_dice : 1.678670
#
#
# dice score (1-dice_loss): 0.974
# dice score (1-dice_loss): 0.460
# dice score (1-dice_loss): 0.511
# dice score (1-dice_loss): 0.293
# dicetotal:1.762
# iteration 146 : loss : 1.184525, loss_seg : 0.607232, loss_seg_dice : 1.761817
#
#
# dice score (1-dice_loss): 0.969
# dice score (1-dice_loss): 0.503
# dice score (1-dice_loss): 0.558
# dice score (1-dice_loss): 0.270
# dicetotal:1.700
# iteration 147 : loss : 1.210001, loss_seg : 0.719587, loss_seg_dice : 1.700415
#
#
# dice score (1-dice_loss): 0.970
# dice score (1-dice_loss): 0.566
# dice score (1-dice_loss): 0.740
# dice score (1-dice_loss): 0.291
# dicetotal:1.433
# iteration 148 : loss : 0.973755, loss_seg : 0.514429, loss_seg_dice : 1.433080
#   2%|▋                            | 37/1501 [07:18<4:52:32, 11.99s/it]
# dice score (1-dice_loss): 0.980
# dice score (1-dice_loss): 0.521
# dice score (1-dice_loss): 0.565
# dice score (1-dice_loss): 0.265
# dicetotal:1.669
# iteration 149 : loss : 1.115573, loss_seg : 0.561672, loss_seg_dice : 1.669474
#
#
# dice score (1-dice_loss): 0.971
# dice score (1-dice_loss): 0.536
# dice score (1-dice_loss): 0.770
# dice score (1-dice_loss): 0.277
# dicetotal:1.446
# iteration 150 : loss : 1.012767, loss_seg : 0.579044, loss_seg_dice : 1.446490
#
#
# dice score (1-dice_loss): 0.985
# dice score (1-dice_loss): 0.575
# dice score (1-dice_loss): 0.696
# dice score (1-dice_loss): 0.274
# dicetotal:1.469
# iteration 151 : loss : 0.939095, loss_seg : 0.408990, loss_seg_dice : 1.469201
#
#
# dice score (1-dice_loss): 0.980
# dice score (1-dice_loss): 0.595
# dice score (1-dice_loss): 0.681
# dice score (1-dice_loss): 0.242
# dicetotal:1.501
# iteration 152 : loss : 1.002591, loss_seg : 0.504378, loss_seg_dice : 1.500804
#   3%|▋                            | 38/1501 [07:30<4:54:29, 12.08s/it]
# dice score (1-dice_loss): 0.968
# dice score (1-dice_loss): 0.423
# dice score (1-dice_loss): 0.668
# dice score (1-dice_loss): 0.231
# dicetotal:1.710
# iteration 153 : loss : 1.108634, loss_seg : 0.507157, loss_seg_dice : 1.710111
#
#
# dice score (1-dice_loss): 0.976
# dice score (1-dice_loss): 0.608
# dice score (1-dice_loss): 0.580
# dice score (1-dice_loss): 0.251
# dicetotal:1.585
# iteration 154 : loss : 1.097996, loss_seg : 0.611241, loss_seg_dice : 1.584751
#
#
# dice score (1-dice_loss): 0.983
# dice score (1-dice_loss): 0.520
# dice score (1-dice_loss): 0.762
# dice score (1-dice_loss): 0.253
# dicetotal:1.482
# iteration 155 : loss : 0.951743, loss_seg : 0.421935, loss_seg_dice : 1.481551
#
#
# dice score (1-dice_loss): 0.973
# dice score (1-dice_loss): 0.524
# dice score (1-dice_loss): 0.564
# dice score (1-dice_loss): 0.253
# dicetotal:1.685
# iteration 156 : loss : 1.148808, loss_seg : 0.612352, loss_seg_dice : 1.685263
#   3%|▊                            | 39/1501 [07:42<4:52:43, 12.01s/it]
# dice score (1-dice_loss): 0.979
# dice score (1-dice_loss): 0.656
# dice score (1-dice_loss): 0.690
# dice score (1-dice_loss): 0.259
# dicetotal:1.416
# iteration 157 : loss : 0.938207, loss_seg : 0.460876, loss_seg_dice : 1.415538
#
#
# dice score (1-dice_loss): 0.968
# dice score (1-dice_loss): 0.603
# dice score (1-dice_loss): 0.788
# dice score (1-dice_loss): 0.223
# dicetotal:1.419
# iteration 158 : loss : 0.885967, loss_seg : 0.353378, loss_seg_dice : 1.418556
#
#
# dice score (1-dice_loss): 0.976
# dice score (1-dice_loss): 0.527
# dice score (1-dice_loss): 0.736
# dice score (1-dice_loss): 0.285
# dicetotal:1.477
# iteration 159 : loss : 1.017230, loss_seg : 0.557674, loss_seg_dice : 1.476785
#
#
# dice score (1-dice_loss): 0.971
# dice score (1-dice_loss): 0.528
# dice score (1-dice_loss): 0.734
# dice score (1-dice_loss): 0.267
# dicetotal:1.500
# iteration 160 : loss : 0.994079, loss_seg : 0.488206, loss_seg_dice : 1.499951
#   3%|▊                            | 40/1501 [07:54<4:46:18, 11.76s/it]
# dice score (1-dice_loss): 0.977
# dice score (1-dice_loss): 0.606
# dice score (1-dice_loss): 0.688
# dice score (1-dice_loss): 0.279
# dicetotal:1.450
# iteration 161 : loss : 0.984433, loss_seg : 0.518692, loss_seg_dice : 1.450175
#
#
# dice score (1-dice_loss): 0.975
# dice score (1-dice_loss): 0.501
# dice score (1-dice_loss): 0.408
# dice score (1-dice_loss): 0.277
# dicetotal:1.839
# iteration 162 : loss : 1.195485, loss_seg : 0.551926, loss_seg_dice : 1.839045
#
#
# dice score (1-dice_loss): 0.973
# dice score (1-dice_loss): 0.534
# dice score (1-dice_loss): 0.514
# dice score (1-dice_loss): 0.182
# dicetotal:1.796
# iteration 163 : loss : 1.210664, loss_seg : 0.625322, loss_seg_dice : 1.796005
#
#
# dice score (1-dice_loss): 0.979
# dice score (1-dice_loss): 0.657
# dice score (1-dice_loss): 0.653
# dice score (1-dice_loss): 0.307
# dicetotal:1.405
# iteration 164 : loss : 0.947181, loss_seg : 0.489724, loss_seg_dice : 1.404638
#   3%|▊                            | 41/1501 [08:06<4:47:49, 11.83s/it]
# dice score (1-dice_loss): 0.975
# dice score (1-dice_loss): 0.487
# dice score (1-dice_loss): 0.668
# dice score (1-dice_loss): 0.184
# dicetotal:1.686
# iteration 165 : loss : 1.135632, loss_seg : 0.585654, loss_seg_dice : 1.685610
#
#
# dice score (1-dice_loss): 0.978
# dice score (1-dice_loss): 0.493
# dice score (1-dice_loss): 0.763
# dice score (1-dice_loss): 0.253
# dicetotal:1.513
# iteration 166 : loss : 0.968439, loss_seg : 0.423646, loss_seg_dice : 1.513231
#
#
# dice score (1-dice_loss): 0.974
# dice score (1-dice_loss): 0.688
# dice score (1-dice_loss): 0.809
# dice score (1-dice_loss): 0.300
# dicetotal:1.229
# iteration 167 : loss : 0.823936, loss_seg : 0.418605, loss_seg_dice : 1.229267
#
#
# dice score (1-dice_loss): 0.976
# dice score (1-dice_loss): 0.643
# dice score (1-dice_loss): 0.724
# dice score (1-dice_loss): 0.261
# dicetotal:1.396
# iteration 168 : loss : 0.952951, loss_seg : 0.509991, loss_seg_dice : 1.395911
#   3%|▊                            | 42/1501 [08:18<4:50:35, 11.95s/it]
# dice score (1-dice_loss): 0.979
# dice score (1-dice_loss): 0.507
# dice score (1-dice_loss): 0.625
# dice score (1-dice_loss): 0.245
# dicetotal:1.644
# iteration 169 : loss : 1.064949, loss_seg : 0.486018, loss_seg_dice : 1.643879
#
#
# dice score (1-dice_loss): 0.975
# dice score (1-dice_loss): 0.604
# dice score (1-dice_loss): 0.702
# dice score (1-dice_loss): 0.276
# dicetotal:1.442
# iteration 170 : loss : 0.947328, loss_seg : 0.452905, loss_seg_dice : 1.441751
#
#
# dice score (1-dice_loss): 0.980
# dice score (1-dice_loss): 0.556
# dice score (1-dice_loss): 0.708
# dice score (1-dice_loss): 0.306
# dicetotal:1.450
# iteration 171 : loss : 0.990905, loss_seg : 0.531949, loss_seg_dice : 1.449861
#
#
# dice score (1-dice_loss): 0.977
# dice score (1-dice_loss): 0.457
# dice score (1-dice_loss): 0.585
# dice score (1-dice_loss): 0.257
# dicetotal:1.723
# iteration 172 : loss : 1.161419, loss_seg : 0.599547, loss_seg_dice : 1.723291
#   3%|▊                            | 43/1501 [08:29<4:49:01, 11.89s/it]
# dice score (1-dice_loss): 0.979
# dice score (1-dice_loss): 0.568
# dice score (1-dice_loss): 0.758
# dice score (1-dice_loss): 0.270
# dicetotal:1.425
# iteration 173 : loss : 0.946813, loss_seg : 0.468713, loss_seg_dice : 1.424912
#
#
# dice score (1-dice_loss): 0.975
# dice score (1-dice_loss): 0.506
# dice score (1-dice_loss): 0.759
# dice score (1-dice_loss): 0.249
# dicetotal:1.511
# iteration 174 : loss : 0.998226, loss_seg : 0.485342, loss_seg_dice : 1.511109
#
#
# dice score (1-dice_loss): 0.980
# dice score (1-dice_loss): 0.564
# dice score (1-dice_loss): 0.738
# dice score (1-dice_loss): 0.302
# dicetotal:1.416
# iteration 175 : loss : 0.905639, loss_seg : 0.395255, loss_seg_dice : 1.416023
#
#
# dice score (1-dice_loss): 0.975
# dice score (1-dice_loss): 0.573
# dice score (1-dice_loss): 0.642
# dice score (1-dice_loss): 0.281
# dicetotal:1.529
# iteration 176 : loss : 1.032589, loss_seg : 0.536457, loss_seg_dice : 1.528721
#   3%|▊                            | 44/1501 [08:41<4:45:25, 11.75s/it]
# dice score (1-dice_loss): 0.982
# dice score (1-dice_loss): 0.509
# dice score (1-dice_loss): 0.749
# dice score (1-dice_loss): 0.299
# dicetotal:1.460
# iteration 177 : loss : 0.907694, loss_seg : 0.355293, loss_seg_dice : 1.460094
#
#
# dice score (1-dice_loss): 0.978
# dice score (1-dice_loss): 0.559
# dice score (1-dice_loss): 0.644
# dice score (1-dice_loss): 0.294
# dicetotal:1.524
# iteration 178 : loss : 1.006514, loss_seg : 0.488796, loss_seg_dice : 1.524231
#
#
# dice score (1-dice_loss): 0.976
# dice score (1-dice_loss): 0.648
# dice score (1-dice_loss): 0.679
# dice score (1-dice_loss): 0.228
# dicetotal:1.470
# iteration 179 : loss : 1.015361, loss_seg : 0.560544, loss_seg_dice : 1.470177
#
#
# dice score (1-dice_loss): 0.978
# dice score (1-dice_loss): 0.555
# dice score (1-dice_loss): 0.666
# dice score (1-dice_loss): 0.253
# dicetotal:1.548
# iteration 180 : loss : 1.045452, loss_seg : 0.543213, loss_seg_dice : 1.547690
#   3%|▊                            | 45/1501 [08:53<4:44:58, 11.74s/it]
# dice score (1-dice_loss): 0.983
# dice score (1-dice_loss): 0.370
# dice score (1-dice_loss): 0.603
# dice score (1-dice_loss): 0.235
# dicetotal:1.809
# iteration 181 : loss : 1.162543, loss_seg : 0.515724, loss_seg_dice : 1.809362
#
#
# dice score (1-dice_loss): 0.981
# dice score (1-dice_loss): 0.569
# dice score (1-dice_loss): 0.777
# dice score (1-dice_loss): 0.289
# dicetotal:1.384
# iteration 182 : loss : 0.886338, loss_seg : 0.389153, loss_seg_dice : 1.383523
#
#
# dice score (1-dice_loss): 0.983
# dice score (1-dice_loss): 0.447
# dice score (1-dice_loss): 0.648
# dice score (1-dice_loss): 0.309
# dicetotal:1.613
# iteration 183 : loss : 1.045444, loss_seg : 0.477738, loss_seg_dice : 1.613150
#
#
# dice score (1-dice_loss): 0.980
# dice score (1-dice_loss): 0.652
# dice score (1-dice_loss): 0.658
# dice score (1-dice_loss): 0.297
# dicetotal:1.413
# iteration 184 : loss : 0.951090, loss_seg : 0.489506, loss_seg_dice : 1.412674
#   3%|▉                            | 46/1501 [09:05<4:46:59, 11.83s/it]
# dice score (1-dice_loss): 0.979
# dice score (1-dice_loss): 0.425
# dice score (1-dice_loss): 0.761
# dice score (1-dice_loss): 0.263
# dicetotal:1.572
# iteration 185 : loss : 1.020196, loss_seg : 0.468581, loss_seg_dice : 1.571811
#
#
# dice score (1-dice_loss): 0.980
# dice score (1-dice_loss): 0.640
# dice score (1-dice_loss): 0.758
# dice score (1-dice_loss): 0.261
# dicetotal:1.361
# iteration 186 : loss : 0.865077, loss_seg : 0.368778, loss_seg_dice : 1.361376
#
#
# dice score (1-dice_loss): 0.977
# dice score (1-dice_loss): 0.611
# dice score (1-dice_loss): 0.788
# dice score (1-dice_loss): 0.224
# dicetotal:1.400
# iteration 187 : loss : 0.886233, loss_seg : 0.372701, loss_seg_dice : 1.399765
#
#
# dice score (1-dice_loss): 0.974
# dice score (1-dice_loss): 0.636
# dice score (1-dice_loss): 0.587
# dice score (1-dice_loss): 0.297
# dicetotal:1.507
# iteration 188 : loss : 1.105027, loss_seg : 0.702849, loss_seg_dice : 1.507204
#   3%|▉                            | 47/1501 [09:16<4:44:28, 11.74s/it]
# dice score (1-dice_loss): 0.977
# dice score (1-dice_loss): 0.649
# dice score (1-dice_loss): 0.623
# dice score (1-dice_loss): 0.269
# dicetotal:1.481
# iteration 189 : loss : 1.012000, loss_seg : 0.542670, loss_seg_dice : 1.481329
#
#
# dice score (1-dice_loss): 0.967
# dice score (1-dice_loss): 0.557
# dice score (1-dice_loss): 0.552
# dice score (1-dice_loss): 0.232
# dicetotal:1.692
# iteration 190 : loss : 1.131607, loss_seg : 0.570803, loss_seg_dice : 1.692410
#
#
# dice score (1-dice_loss): 0.982
# dice score (1-dice_loss): 0.578
# dice score (1-dice_loss): 0.738
# dice score (1-dice_loss): 0.247
# dicetotal:1.456
# iteration 191 : loss : 0.923794, loss_seg : 0.391941, loss_seg_dice : 1.455646
#
#
# dice score (1-dice_loss): 0.971
# dice score (1-dice_loss): 0.534
# dice score (1-dice_loss): 0.718
# dice score (1-dice_loss): 0.247
# dicetotal:1.531
# iteration 192 : loss : 1.022647, loss_seg : 0.514783, loss_seg_dice : 1.530511
#   3%|▉                            | 48/1501 [09:28<4:42:26, 11.66s/it]
# dice score (1-dice_loss): 0.979
# dice score (1-dice_loss): 0.593
# dice score (1-dice_loss): 0.660
# dice score (1-dice_loss): 0.241
# dicetotal:1.528
# iteration 193 : loss : 0.996583, loss_seg : 0.465313, loss_seg_dice : 1.527853
#
#
# dice score (1-dice_loss): 0.977
# dice score (1-dice_loss): 0.624
# dice score (1-dice_loss): 0.663
# dice score (1-dice_loss): 0.267
# dicetotal:1.469
# iteration 194 : loss : 1.056994, loss_seg : 0.644973, loss_seg_dice : 1.469015
#
#
# dice score (1-dice_loss): 0.976
# dice score (1-dice_loss): 0.475
# dice score (1-dice_loss): 0.713
# dice score (1-dice_loss): 0.251
# dicetotal:1.584
# iteration 195 : loss : 1.022408, loss_seg : 0.460546, loss_seg_dice : 1.584270
#
#
# dice score (1-dice_loss): 0.983
# dice score (1-dice_loss): 0.624
# dice score (1-dice_loss): 0.729
# dice score (1-dice_loss): 0.259
# dicetotal:1.405
# iteration 196 : loss : 0.919975, loss_seg : 0.435153, loss_seg_dice : 1.404797
#   3%|▉                            | 49/1501 [09:40<4:45:40, 11.81s/it]
# dice score (1-dice_loss): 0.980
# dice score (1-dice_loss): 0.584
# dice score (1-dice_loss): 0.675
# dice score (1-dice_loss): 0.274
# dicetotal:1.487
# iteration 197 : loss : 1.038646, loss_seg : 0.590279, loss_seg_dice : 1.487012
#
#
# dice score (1-dice_loss): 0.974
# dice score (1-dice_loss): 0.615
# dice score (1-dice_loss): 0.640
# ...
#  99%|██████████████████████████▋| 1484/1501 [4:53:55<03:25, 12.10s/it]
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.930
# dice score (1-dice_loss): 0.947
# dice score (1-dice_loss): 0.895
# dicetotal:0.232
# iteration 5937 : loss : 0.149864, loss_seg : 0.068153, loss_seg_dice : 0.231576
#
#
# dice score (1-dice_loss): 0.996
# dice score (1-dice_loss): 0.943
# dice score (1-dice_loss): 0.937
# dice score (1-dice_loss): 0.886
# dicetotal:0.238
# iteration 5938 : loss : 0.167118, loss_seg : 0.096689, loss_seg_dice : 0.237547
#
#
# dice score (1-dice_loss): 0.996
# dice score (1-dice_loss): 0.902
# dice score (1-dice_loss): 0.911
# dice score (1-dice_loss): 0.703
# dicetotal:0.488
# iteration 5939 : loss : 0.342511, loss_seg : 0.197238, loss_seg_dice : 0.487784
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.944
# dice score (1-dice_loss): 0.965
# dice score (1-dice_loss): 0.926
# dicetotal:0.168
# iteration 5940 : loss : 0.121941, loss_seg : 0.076179, loss_seg_dice : 0.167702
#  99%|██████████████████████████▋| 1485/1501 [4:54:07<03:12, 12.02s/it]
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.957
# dice score (1-dice_loss): 0.947
# dice score (1-dice_loss): 0.923
# dicetotal:0.176
# iteration 5941 : loss : 0.130280, loss_seg : 0.084620, loss_seg_dice : 0.175940
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.937
# dice score (1-dice_loss): 0.957
# dice score (1-dice_loss): 0.878
# dicetotal:0.231
# iteration 5942 : loss : 0.157597, loss_seg : 0.083974, loss_seg_dice : 0.231221
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.889
# dice score (1-dice_loss): 0.851
# dice score (1-dice_loss): 0.883
# dicetotal:0.381
# iteration 5943 : loss : 0.297361, loss_seg : 0.214134, loss_seg_dice : 0.380588
#
#
# dice score (1-dice_loss): 0.998
# dice score (1-dice_loss): 0.967
# dice score (1-dice_loss): 0.945
# dice score (1-dice_loss): 0.907
# dicetotal:0.184
# iteration 5944 : loss : 0.132381, loss_seg : 0.080466, loss_seg_dice : 0.184296
#  99%|██████████████████████████▋| 1486/1501 [4:54:19<03:00, 12.04s/it]
# dice score (1-dice_loss): 0.996
# dice score (1-dice_loss): 0.954
# dice score (1-dice_loss): 0.928
# dice score (1-dice_loss): 0.915
# dicetotal:0.206
# iteration 5945 : loss : 0.141964, loss_seg : 0.077886, loss_seg_dice : 0.206043
#
#
# dice score (1-dice_loss): 0.998
# dice score (1-dice_loss): 0.960
# dice score (1-dice_loss): 0.944
# dice score (1-dice_loss): 0.857
# dicetotal:0.241
# iteration 5946 : loss : 0.157840, loss_seg : 0.074243, loss_seg_dice : 0.241436
#
#
# dice score (1-dice_loss): 0.995
# dice score (1-dice_loss): 0.845
# dice score (1-dice_loss): 0.885
# dice score (1-dice_loss): 0.794
# dicetotal:0.481
# iteration 5947 : loss : 0.325333, loss_seg : 0.169314, loss_seg_dice : 0.481352
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.948
# dice score (1-dice_loss): 0.949
# dice score (1-dice_loss): 0.891
# dicetotal:0.215
# iteration 5948 : loss : 0.152289, loss_seg : 0.089714, loss_seg_dice : 0.214865
#  99%|██████████████████████████▋| 1487/1501 [4:54:31<02:46, 11.91s/it]
# dice score (1-dice_loss): 0.990
# dice score (1-dice_loss): 0.935
# dice score (1-dice_loss): 0.822
# dice score (1-dice_loss): 0.823
# dicetotal:0.429
# iteration 5949 : loss : 0.293268, loss_seg : 0.157149, loss_seg_dice : 0.429387
#
#
# dice score (1-dice_loss): 0.998
# dice score (1-dice_loss): 0.936
# dice score (1-dice_loss): 0.963
# dice score (1-dice_loss): 0.815
# dicetotal:0.288
# iteration 5950 : loss : 0.196279, loss_seg : 0.104435, loss_seg_dice : 0.288124
#
#
# dice score (1-dice_loss): 0.996
# dice score (1-dice_loss): 0.916
# dice score (1-dice_loss): 0.911
# dice score (1-dice_loss): 0.757
# dicetotal:0.419
# iteration 5951 : loss : 0.305658, loss_seg : 0.191838, loss_seg_dice : 0.419478
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.959
# dice score (1-dice_loss): 0.956
# dice score (1-dice_loss): 0.920
# dicetotal:0.168
# iteration 5952 : loss : 0.118394, loss_seg : 0.068893, loss_seg_dice : 0.167895
#  99%|██████████████████████████▊| 1488/1501 [4:54:43<02:35, 11.96s/it]
# dice score (1-dice_loss): 0.996
# dice score (1-dice_loss): 0.933
# dice score (1-dice_loss): 0.954
# dice score (1-dice_loss): 0.891
# dicetotal:0.225
# iteration 5953 : loss : 0.163727, loss_seg : 0.102160, loss_seg_dice : 0.225293
#
#
# dice score (1-dice_loss): 0.998
# dice score (1-dice_loss): 0.903
# dice score (1-dice_loss): 0.963
# dice score (1-dice_loss): 0.789
# dicetotal:0.346
# iteration 5954 : loss : 0.231760, loss_seg : 0.117584, loss_seg_dice : 0.345937
#
#
# dice score (1-dice_loss): 0.996
# dice score (1-dice_loss): 0.933
# dice score (1-dice_loss): 0.921
# dice score (1-dice_loss): 0.892
# dicetotal:0.258
# iteration 5955 : loss : 0.186107, loss_seg : 0.114445, loss_seg_dice : 0.257769
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.932
# dice score (1-dice_loss): 0.943
# dice score (1-dice_loss): 0.893
# dicetotal:0.235
# iteration 5956 : loss : 0.155962, loss_seg : 0.077271, loss_seg_dice : 0.234654
#  99%|██████████████████████████▊| 1489/1501 [4:54:55<02:23, 11.92s/it]
# dice score (1-dice_loss): 0.998
# dice score (1-dice_loss): 0.851
# dice score (1-dice_loss): 0.884
# dice score (1-dice_loss): 0.823
# dicetotal:0.444
# iteration 5957 : loss : 0.313020, loss_seg : 0.182175, loss_seg_dice : 0.443865
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.931
# dice score (1-dice_loss): 0.949
# dice score (1-dice_loss): 0.883
# dicetotal:0.240
# iteration 5958 : loss : 0.176535, loss_seg : 0.113046, loss_seg_dice : 0.240025
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.967
# dice score (1-dice_loss): 0.941
# dice score (1-dice_loss): 0.917
# dicetotal:0.178
# iteration 5959 : loss : 0.123367, loss_seg : 0.068530, loss_seg_dice : 0.178205
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.942
# dice score (1-dice_loss): 0.945
# dice score (1-dice_loss): 0.850
# dicetotal:0.266
# iteration 5960 : loss : 0.191884, loss_seg : 0.117971, loss_seg_dice : 0.265797
#  99%|██████████████████████████▊| 1490/1501 [4:55:07<02:10, 11.88s/it]
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.969
# dice score (1-dice_loss): 0.949
# dice score (1-dice_loss): 0.903
# dicetotal:0.182
# iteration 5961 : loss : 0.124018, loss_seg : 0.066249, loss_seg_dice : 0.181787
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.922
# dice score (1-dice_loss): 0.944
# dice score (1-dice_loss): 0.842
# dicetotal:0.296
# iteration 5962 : loss : 0.218663, loss_seg : 0.141587, loss_seg_dice : 0.295739
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.960
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.926
# dicetotal:0.162
# iteration 5963 : loss : 0.116356, loss_seg : 0.070569, loss_seg_dice : 0.162143
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.954
# dice score (1-dice_loss): 0.928
# dice score (1-dice_loss): 0.862
# dicetotal:0.259
# iteration 5964 : loss : 0.187230, loss_seg : 0.115661, loss_seg_dice : 0.258799
#  99%|██████████████████████████▊| 1491/1501 [4:55:20<02:04, 12.45s/it]
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.945
# dice score (1-dice_loss): 0.903
# dice score (1-dice_loss): 0.819
# dicetotal:0.336
# iteration 5965 : loss : 0.229831, loss_seg : 0.123343, loss_seg_dice : 0.336319
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.950
# dice score (1-dice_loss): 0.956
# dice score (1-dice_loss): 0.923
# dicetotal:0.173
# iteration 5966 : loss : 0.127829, loss_seg : 0.082456, loss_seg_dice : 0.173203
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.962
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.918
# dicetotal:0.169
# iteration 5967 : loss : 0.128968, loss_seg : 0.089426, loss_seg_dice : 0.168509
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.968
# dice score (1-dice_loss): 0.949
# dice score (1-dice_loss): 0.866
# dicetotal:0.220
# iteration 5968 : loss : 0.149811, loss_seg : 0.079685, loss_seg_dice : 0.219937
#  99%|██████████████████████████▊| 1492/1501 [4:55:32<01:49, 12.20s/it]
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.953
# dice score (1-dice_loss): 0.898
# dicetotal:0.197
# iteration 5969 : loss : 0.135146, loss_seg : 0.072914, loss_seg_dice : 0.197379
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.830
# dice score (1-dice_loss): 0.927
# dice score (1-dice_loss): 0.557
# dicetotal:0.689
# iteration 5970 : loss : 0.440953, loss_seg : 0.192873, loss_seg_dice : 0.689033
#
#
# dice score (1-dice_loss): 0.998
# dice score (1-dice_loss): 0.968
# dice score (1-dice_loss): 0.950
# dice score (1-dice_loss): 0.904
# dicetotal:0.181
# iteration 5971 : loss : 0.132997, loss_seg : 0.085138, loss_seg_dice : 0.180855
#
#
# dice score (1-dice_loss): 0.998
# dice score (1-dice_loss): 0.902
# dice score (1-dice_loss): 0.912
# dice score (1-dice_loss): 0.819
# dicetotal:0.369
# iteration 5972 : loss : 0.263636, loss_seg : 0.158616, loss_seg_dice : 0.368657
#  99%|██████████████████████████▊| 1493/1501 [4:55:44<01:37, 12.14s/it]
# dice score (1-dice_loss): 0.998
# dice score (1-dice_loss): 0.944
# dice score (1-dice_loss): 0.934
# dice score (1-dice_loss): 0.856
# dicetotal:0.269
# iteration 5973 : loss : 0.179910, loss_seg : 0.091271, loss_seg_dice : 0.268549
#
#
# dice score (1-dice_loss): 0.988
# dice score (1-dice_loss): 0.850
# dice score (1-dice_loss): 0.903
# dice score (1-dice_loss): 0.743
# dicetotal:0.516
# iteration 5974 : loss : 0.337796, loss_seg : 0.159764, loss_seg_dice : 0.515827
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.966
# dice score (1-dice_loss): 0.958
# dice score (1-dice_loss): 0.942
# dicetotal:0.137
# iteration 5975 : loss : 0.104636, loss_seg : 0.072330, loss_seg_dice : 0.136942
#
#
# dice score (1-dice_loss): 0.996
# dice score (1-dice_loss): 0.963
# dice score (1-dice_loss): 0.940
# dice score (1-dice_loss): 0.914
# dicetotal:0.186
# iteration 5976 : loss : 0.132734, loss_seg : 0.079554, loss_seg_dice : 0.185913
# 100%|██████████████████████████▊| 1494/1501 [4:55:57<01:25, 12.28s/it]
# dice score (1-dice_loss): 0.998
# dice score (1-dice_loss): 0.914
# dice score (1-dice_loss): 0.960
# dice score (1-dice_loss): 0.855
# dicetotal:0.273
# iteration 5977 : loss : 0.180678, loss_seg : 0.088228, loss_seg_dice : 0.273128
#
#
# dice score (1-dice_loss): 0.975
# dice score (1-dice_loss): 0.669
# dice score (1-dice_loss): 0.928
# dice score (1-dice_loss): 0.812
# dicetotal:0.616
# iteration 5978 : loss : 0.416943, loss_seg : 0.217692, loss_seg_dice : 0.616193
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.937
# dice score (1-dice_loss): 0.949
# dice score (1-dice_loss): 0.900
# dicetotal:0.216
# iteration 5979 : loss : 0.136033, loss_seg : 0.055686, loss_seg_dice : 0.216380
#
#
# dice score (1-dice_loss): 0.996
# dice score (1-dice_loss): 0.948
# dice score (1-dice_loss): 0.932
# dice score (1-dice_loss): 0.880
# dicetotal:0.244
# iteration 5980 : loss : 0.176793, loss_seg : 0.109857, loss_seg_dice : 0.243730
# 100%|██████████████████████████▉| 1495/1501 [4:56:08<01:12, 12.13s/it]
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.940
# dice score (1-dice_loss): 0.959
# dice score (1-dice_loss): 0.842
# dicetotal:0.262
# iteration 5981 : loss : 0.188862, loss_seg : 0.115286, loss_seg_dice : 0.262438
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.937
# dice score (1-dice_loss): 0.940
# dice score (1-dice_loss): 0.857
# dicetotal:0.270
# iteration 5982 : loss : 0.192631, loss_seg : 0.115717, loss_seg_dice : 0.269545
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.900
# dice score (1-dice_loss): 0.882
# dice score (1-dice_loss): 0.894
# dicetotal:0.326
# iteration 5983 : loss : 0.243243, loss_seg : 0.160404, loss_seg_dice : 0.326082
#
#
# dice score (1-dice_loss): 0.996
# dice score (1-dice_loss): 0.928
# dice score (1-dice_loss): 0.912
# dice score (1-dice_loss): 0.750
# dicetotal:0.414
# iteration 5984 : loss : 0.294004, loss_seg : 0.174130, loss_seg_dice : 0.413877
# 100%|██████████████████████████▉| 1496/1501 [4:56:20<01:00, 12.07s/it]
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.945
# dice score (1-dice_loss): 0.947
# dice score (1-dice_loss): 0.808
# dicetotal:0.303
# iteration 5985 : loss : 0.214508, loss_seg : 0.126378, loss_seg_dice : 0.302639
#
#
# dice score (1-dice_loss): 0.998
# dice score (1-dice_loss): 0.963
# dice score (1-dice_loss): 0.966
# dice score (1-dice_loss): 0.922
# dicetotal:0.151
# iteration 5986 : loss : 0.108322, loss_seg : 0.065220, loss_seg_dice : 0.151423
#
#
# dice score (1-dice_loss): 0.998
# dice score (1-dice_loss): 0.954
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.883
# dicetotal:0.211
# iteration 5987 : loss : 0.139411, loss_seg : 0.067716, loss_seg_dice : 0.211107
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.941
# dice score (1-dice_loss): 0.945
# dice score (1-dice_loss): 0.884
# dicetotal:0.233
# iteration 5988 : loss : 0.167110, loss_seg : 0.101537, loss_seg_dice : 0.232683
# 100%|██████████████████████████▉| 1497/1501 [4:56:32<00:47, 11.98s/it]
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.938
# dice score (1-dice_loss): 0.948
# dice score (1-dice_loss): 0.893
# dicetotal:0.223
# iteration 5989 : loss : 0.165729, loss_seg : 0.107991, loss_seg_dice : 0.223468
#
#
# dice score (1-dice_loss): 0.998
# dice score (1-dice_loss): 0.942
# dice score (1-dice_loss): 0.962
# dice score (1-dice_loss): 0.913
# dicetotal:0.185
# iteration 5990 : loss : 0.121766, loss_seg : 0.058153, loss_seg_dice : 0.185380
#
#
# dice score (1-dice_loss): 0.998
# dice score (1-dice_loss): 0.966
# dice score (1-dice_loss): 0.959
# dice score (1-dice_loss): 0.918
# dicetotal:0.160
# iteration 5991 : loss : 0.106173, loss_seg : 0.052479, loss_seg_dice : 0.159866
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.946
# dice score (1-dice_loss): 0.949
# dice score (1-dice_loss): 0.905
# dicetotal:0.203
# iteration 5992 : loss : 0.151087, loss_seg : 0.099211, loss_seg_dice : 0.202964
# 100%|██████████████████████████▉| 1498/1501 [4:56:44<00:35, 11.98s/it]
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.924
# dicetotal:0.169
# iteration 5993 : loss : 0.114728, loss_seg : 0.060618, loss_seg_dice : 0.168838
#
#
# dice score (1-dice_loss): 0.998
# dice score (1-dice_loss): 0.961
# dice score (1-dice_loss): 0.955
# dice score (1-dice_loss): 0.830
# dicetotal:0.255
# iteration 5994 : loss : 0.150329, loss_seg : 0.045447, loss_seg_dice : 0.255210
#
#
# dice score (1-dice_loss): 0.994
# dice score (1-dice_loss): 0.949
# dice score (1-dice_loss): 0.912
# dice score (1-dice_loss): 0.873
# dicetotal:0.272
# iteration 5995 : loss : 0.206893, loss_seg : 0.141574, loss_seg_dice : 0.272213
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.912
# dice score (1-dice_loss): 0.942
# dice score (1-dice_loss): 0.747
# dicetotal:0.402
# iteration 5996 : loss : 0.303886, loss_seg : 0.205597, loss_seg_dice : 0.402174
# 100%|██████████████████████████▉| 1499/1501 [4:56:56<00:23, 11.99s/it]
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.947
# dice score (1-dice_loss): 0.942
# dice score (1-dice_loss): 0.888
# dicetotal:0.227
# iteration 5997 : loss : 0.163643, loss_seg : 0.100426, loss_seg_dice : 0.226859
#
#
# dice score (1-dice_loss): 0.998
# dice score (1-dice_loss): 0.918
# dice score (1-dice_loss): 0.960
# dice score (1-dice_loss): 0.808
# dicetotal:0.316
# iteration 5998 : loss : 0.230893, loss_seg : 0.145897, loss_seg_dice : 0.315889
#
#
# dice score (1-dice_loss): 0.997
# dice score (1-dice_loss): 0.914
# dice score (1-dice_loss): 0.897
# dice score (1-dice_loss): 0.766
# dicetotal:0.427
# iteration 5999 : loss : 0.311115, loss_seg : 0.195400, loss_seg_dice : 0.426831
#
#
# dice score (1-dice_loss): 0.998
# dice score (1-dice_loss): 0.951
# dice score (1-dice_loss): 0.958
# dice score (1-dice_loss): 0.901
# dicetotal:0.192
# iteration 6000 : loss : 0.136428, loss_seg : 0.080525, loss_seg_dice : 0.192331
# save model to ../model/vnet_supervisedonly_dp/iter_6000.pth
# 100%|██████████████████████████▉| 1500/1501 [4:57:08<00:11, 11.93s/it]
# dice score (1-dice_loss): 0.996
# dice score (1-dice_loss): 0.921
# dice score (1-dice_loss): 0.927
# dice score (1-dice_loss): 0.825
# dicetotal:0.331
# iteration 6001 : loss : 0.238027, loss_seg : 0.145465, loss_seg_dice : 0.330589
# save model to ../model/vnet_supervisedonly_dp/iter_6001.pth
